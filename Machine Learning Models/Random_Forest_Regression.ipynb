# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy 
import os
# import seaborn as sns
# import scipy.stats as stats
import unittest

# %%
df_battery = pd.read_csv('Battery_Dataset.csv')

# %%
import csv
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold 
import math

from notebook.services.config import ConfigManager
cm = ConfigManager().update('notebook', {'limit_output': 1000})
import statistics as stcs
import scipy.stats as stats

import sklearn as sk
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler,scale,MinMaxScaler
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from scipy.stats import uniform,expon
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

# %%
#One hot encoding (alphebetical order)
ohe = OneHotEncoder()
ACE = df_battery.loc[:,['anode','cathode','electrolyte']]
ACE = ohe.fit_transform(ACE)
ACE = pd.DataFrame(ACE.toarray())

ACE_col_name = ['A1','C1','C2','C3','E1','E2','E3']
for i in range(len(ACE.columns)):
    ACE = ACE.rename({ACE.columns[i]: ACE_col_name[i]}, axis=1) 
    
df_battery = pd.concat([ACE, df_battery],axis=1)

# %%
data = df_battery

np.random.seed(66)
def data_split (data, test_ratio):
    
    total_row = df_battery.shape[0]
    test_row = round(total_row *test_ratio)
    train_row = total_row - test_row
    
    indices =np.random.permutation(total_row)
    train_indx, test_idx =indices[:train_row], indices[train_row:]
    train,test = df_battery.iloc[train_indx,:], df_battery.iloc[test_idx,:]

    X_test = test[['A1','C1','C2','C3','E1','E2','E3','Cycle','temperature','discharge_crate']]
#    y_test = test[['Charge_Capacity (Ah)']]
#    y_test = test[['Discharge_Capacity (Ah)']]
#    y_test = test[['Charge_Energy (Wh)']]
#    y_test = test[['Discharge_Energy (Wh)']]
    y_test = test[['Coulombic_Efficiency (%)']]
#    y_test = test[['Energy_Efficiency (%)']]
    X_train = train[['A1','C1','C2','C3','E1','E2','E3','Cycle','temperature','discharge_crate']]
#    y_train = train[['Charge_Capacity (Ah)']]
#    y_train = train[['Discharge_Capacity (Ah)']]
#    y_train = train[['Charge_Energy (Wh)']]
#    y_train = train[['Discharge_Energy (Wh)']]
    y_train = train[['Coulombic_Efficiency (%)']]
#    y_train = train[['Energy_Efficiency (%)']]
    return train,test,X_train,y_train,X_test,y_test
    
train,test,X_train,y_train,X_test,y_test = data_split(data,0.2)

# %%
kf = KFold(n_splits=10,random_state =66,shuffle= True)

# %%
rand_para = {'n_estimators':[100, 200, 300, 400],
             'max_features':[1, 3, 5, 7],
             'max_depth': [6, 7, 8, 9]}
reg=RandomForestRegressor(random_state = 66,min_samples_leaf =1,min_samples_split=2)

n_iteration = 200
Scoring = ['explained_variance','neg_mean_squared_error',"r2"]
random_search = RandomizedSearchCV(reg,param_distributions=rand_para,cv =5,
error_score=0,random_state=66,return_train_score=True,n_jobs=-1,n_iter=n_iteration,verbose=10,refit=True)

random_search.fit(X_train,y_train)

#y_predict=random_search.predict(X_test)
#math.sqrt(stcs.mean((y_predict-y_test)**2))
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:292: UserWarning: The total space of parameters 64 is smaller than n_iter=200. Running 64 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...
# [CV 5/5; 8/64] START max_depth=6, max_features=3, n_estimators=400..............
# [CV 5/5; 8/64] END max_depth=6, max_features=3, n_estimators=400;, score=(train=0.505, test=-3.461) total time=   4.2s
# [CV 3/5; 11/64] START max_depth=6, max_features=5, n_estimators=300.............
# [CV 3/5; 11/64] END max_depth=6, max_features=5, n_estimators=300;, score=(train=0.513, test=-4.407) total time=   2.9s
# [CV 1/5; 13/64] START max_depth=6, max_features=7, n_estimators=100.............
# [CV 1/5; 13/64] END max_depth=6, max_features=7, n_estimators=100;, score=(train=0.383, test=-1.579) total time=   1.0s
# [CV 4/5; 13/64] START max_depth=6, max_features=7, n_estimators=100.............
# [CV 4/5; 13/64] END max_depth=6, max_features=7, n_estimators=100;, score=(train=0.328, test=0.080) total time=   1.0s
# [CV 5/5; 14/64] START max_depth=6, max_features=7, n_estimators=200.............
# [CV 5/5; 14/64] END max_depth=6, max_features=7, n_estimators=200;, score=(train=0.508, test=-3.264) total time=   2.0s
# [CV 3/5; 16/64] START max_depth=6, max_features=7, n_estimators=400.............
# [CV 3/5; 16/64] END max_depth=6, max_features=7, n_estimators=400;, score=(train=0.513, test=-4.519) total time=   3.8s
# [CV 4/5; 18/64] START max_depth=7, max_features=1, n_estimators=200.............
# [CV 4/5; 18/64] END max_depth=7, max_features=1, n_estimators=200;, score=(train=0.345, test=0.115) total time=   1.9s
# [CV 2/5; 20/64] START max_depth=7, max_features=1, n_estimators=400.............
# [CV 2/5; 20/64] END max_depth=7, max_features=1, n_estimators=400;, score=(train=0.754, test=-0.078) total time=   3.8s
# [CV 3/5; 22/64] START max_depth=7, max_features=3, n_estimators=200.............
# [CV 3/5; 22/64] END max_depth=7, max_features=3, n_estimators=200;, score=(train=0.515, test=-4.211) total time=   1.9s
# [CV 5/5; 23/64] START max_depth=7, max_features=3, n_estimators=300.............
# [CV 5/5; 23/64] END max_depth=7, max_features=3, n_estimators=300;, score=(train=0.515, test=-3.421) total time=   2.9s
# [CV 3/5; 25/64] START max_depth=7, max_features=5, n_estimators=100.............
# [CV 3/5; 25/64] END max_depth=7, max_features=5, n_estimators=100;, score=(train=0.490, test=-2.941) total time=   1.0s
# [CV 1/5; 26/64] START max_depth=7, max_features=5, n_estimators=200.............
# [CV 1/5; 26/64] END max_depth=7, max_features=5, n_estimators=200;, score=(train=0.388, test=-2.326) total time=   1.9s
# [CV 3/5; 27/64] START max_depth=7, max_features=5, n_estimators=300.............
# [CV 3/5; 27/64] END max_depth=7, max_features=5, n_estimators=300;, score=(train=0.520, test=-4.480) total time=   2.8s
# [CV 1/5; 29/64] START max_depth=7, max_features=7, n_estimators=100.............
# [CV 1/5; 29/64] END max_depth=7, max_features=7, n_estimators=100;, score=(train=0.389, test=-2.152) total time=   1.0s
# [CV 4/5; 29/64] START max_depth=7, max_features=7, n_estimators=100.............
# [CV 4/5; 29/64] END max_depth=7, max_features=7, n_estimators=100;, score=(train=0.330, test=0.092) total time=   1.0s
# [CV 5/5; 30/64] START max_depth=7, max_features=7, n_estimators=200.............
# [CV 5/5; 30/64] END max_depth=7, max_features=7, n_estimators=200;, score=(train=0.513, test=-3.284) total time=   2.0s
# [CV 3/5; 32/64] START max_depth=7, max_features=7, n_estimators=400.............
# [CV 3/5; 32/64] END max_depth=7, max_features=7, n_estimators=400;, score=(train=0.519, test=-4.542) total time=   3.9s
# [CV 4/5; 34/64] START max_depth=8, max_features=1, n_estimators=200.............
# [CV 4/5; 34/64] END max_depth=8, max_features=1, n_estimators=200;, score=(train=0.348, test=0.128) total time=   1.9s
# [CV 2/5; 36/64] START max_depth=8, max_features=1, n_estimators=400.............
# [CV 2/5; 36/64] END max_depth=8, max_features=1, n_estimators=400;, score=(train=0.763, test=-0.080) total time=   3.7s
# [CV 1/5; 38/64] START max_depth=8, max_features=3, n_estimators=200.............
# [CV 1/5; 38/64] END max_depth=8, max_features=3, n_estimators=200;, score=(train=0.392, test=-2.614) total time=   1.9s
# [CV 3/5; 39/64] START max_depth=8, max_features=3, n_estimators=300.............
# [CV 3/5; 39/64] END max_depth=8, max_features=3, n_estimators=300;, score=(train=0.523, test=-4.500) total time=   2.9s
# [CV 1/5; 41/64] START max_depth=8, max_features=5, n_estimators=100.............
# [CV 1/5; 41/64] END max_depth=8, max_features=5, n_estimators=100;, score=(train=0.392, test=-2.017) total time=   1.0s
# [CV 4/5; 41/64] START max_depth=8, max_features=5, n_estimators=100.............
# [CV 4/5; 41/64] END max_depth=8, max_features=5, n_estimators=100;, score=(train=0.331, test=0.100) total time=   1.1s
# [CV 5/5; 42/64] START max_depth=8, max_features=5, n_estimators=200.............
# [CV 5/5; 42/64] END max_depth=8, max_features=5, n_estimators=200;, score=(train=0.516, test=-3.300) total time=   1.9s
# [CV 2/5; 44/64] START max_depth=8, max_features=5, n_estimators=400.............
# [CV 2/5; 44/64] END max_depth=8, max_features=5, n_estimators=400;, score=(train=0.758, test=-0.088) total time=   3.9s
# [CV 3/5; 46/64] START max_depth=8, max_features=7, n_estimators=200.............
# [CV 3/5; 46/64] END max_depth=8, max_features=7, n_estimators=200;, score=(train=0.517, test=-4.168) total time=   1.9s
# [CV 4/5; 47/64] START max_depth=8, max_features=7, n_estimators=300.............
# [CV 4/5; 47/64] END max_depth=8, max_features=7, n_estimators=300;, score=(train=0.351, test=0.099) total time=   2.3s
# [CV 3/5; 49/64] START max_depth=9, max_features=1, n_estimators=100.............
# [CV 3/5; 49/64] END max_depth=9, max_features=1, n_estimators=100;, score=(train=0.494, test=-3.073) total time=   0.8s
# [CV 3/5; 50/64] START max_depth=9, max_features=1, n_estimators=200.............
# [CV 3/5; 50/64] END max_depth=9, max_features=1, n_estimators=200;, score=(train=0.520, test=-4.243) total time=   1.7s
# [CV 5/5; 51/64] START max_depth=9, max_features=1, n_estimators=300.............
# [CV 5/5; 51/64] END max_depth=9, max_features=1, n_estimators=300;, score=(train=0.523, test=-3.429) total time=   2.3s
# [CV 3/5; 53/64] START max_depth=9, max_features=3, n_estimators=100.............
# [CV 3/5; 53/64] END max_depth=9, max_features=3, n_estimators=100;, score=(train=0.492, test=-3.095) total time=   0.8s
# [CV 5/5; 53/64] START max_depth=9, max_features=3, n_estimators=100.............
# [CV 5/5; 53/64] END max_depth=9, max_features=3, n_estimators=100;, score=(train=0.498, test=-2.576) total time=   0.8s
# [CV 4/5; 54/64] START max_depth=9, max_features=3, n_estimators=200.............
# [CV 4/5; 54/64] END max_depth=9, max_features=3, n_estimators=200;, score=(train=0.348, test=0.128) total time=   1.9s
# [CV 1/5; 56/64] START max_depth=9, max_features=3, n_estimators=400.............
# [CV 1/5; 56/64] END max_depth=9, max_features=3, n_estimators=400;, score=(train=0.393, test=-2.486) total time=   3.2s
# [CV 3/5; 58/64] START max_depth=9, max_features=5, n_estimators=200.............
# [CV 3/5; 58/64] END max_depth=9, max_features=5, n_estimators=200;, score=(train=0.521, test=-4.180) total time=   1.3s
# [CV 3/5; 59/64] START max_depth=9, max_features=5, n_estimators=300.............
# [CV 1/5; 1/64] START max_depth=6, max_features=1, n_estimators=100..............
# [CV 1/5; 1/64] END max_depth=6, max_features=1, n_estimators=100;, score=(train=0.369, test=-1.747) total time=   1.2s
# [CV 1/5; 3/64] START max_depth=6, max_features=1, n_estimators=300..............
# [CV 1/5; 3/64] END max_depth=6, max_features=1, n_estimators=300;, score=(train=0.372, test=-1.651) total time=   3.2s
# [CV 4/5; 4/64] START max_depth=6, max_features=1, n_estimators=400..............
# [CV 4/5; 4/64] END max_depth=6, max_features=1, n_estimators=400;, score=(train=0.341, test=0.095) total time=   4.8s
# [CV 2/5; 7/64] START max_depth=6, max_features=3, n_estimators=300..............
# [CV 2/5; 7/64] END max_depth=6, max_features=3, n_estimators=300;, score=(train=0.735, test=-0.083) total time=   4.1s
# [CV 1/5; 9/64] START max_depth=6, max_features=5, n_estimators=100..............
# [CV 1/5; 9/64] END max_depth=6, max_features=5, n_estimators=100;, score=(train=0.381, test=-2.617) total time=   1.4s
# [CV 5/5; 9/64] START max_depth=6, max_features=5, n_estimators=100..............
# [CV 5/5; 9/64] END max_depth=6, max_features=5, n_estimators=100;, score=(train=0.487, test=-2.616) total time=   1.2s
# [CV 2/5; 11/64] START max_depth=6, max_features=5, n_estimators=300.............
# [CV 2/5; 11/64] END max_depth=6, max_features=5, n_estimators=300;, score=(train=0.726, test=-0.080) total time=   3.1s
# [CV 5/5; 12/64] START max_depth=6, max_features=5, n_estimators=400.............
# [CV 5/5; 12/64] END max_depth=6, max_features=5, n_estimators=400;, score=(train=0.513, test=-3.602) total time=   3.8s
# [CV 3/5; 15/64] START max_depth=6, max_features=7, n_estimators=300.............
# [CV 3/5; 15/64] END max_depth=6, max_features=7, n_estimators=300;, score=(train=0.514, test=-4.472) total time=   2.9s
# [CV 1/5; 17/64] START max_depth=7, max_features=1, n_estimators=100.............
# [CV 1/5; 17/64] END max_depth=7, max_features=1, n_estimators=100;, score=(train=0.389, test=-2.017) total time=   1.0s
# [CV 4/5; 17/64] START max_depth=7, max_features=1, n_estimators=100.............
# [CV 4/5; 17/64] END max_depth=7, max_features=1, n_estimators=100;, score=(train=0.330, test=0.104) total time=   1.0s
# [CV 5/5; 18/64] START max_depth=7, max_features=1, n_estimators=200.............
# [CV 5/5; 18/64] END max_depth=7, max_features=1, n_estimators=200;, score=(train=0.511, test=-3.155) total time=   1.9s
# [CV 3/5; 20/64] START max_depth=7, max_features=1, n_estimators=400.............
# [CV 3/5; 20/64] END max_depth=7, max_features=1, n_estimators=400;, score=(train=0.517, test=-4.620) total time=   3.8s
# [CV 4/5; 22/64] START max_depth=7, max_features=3, n_estimators=200.............
# [CV 4/5; 22/64] END max_depth=7, max_features=3, n_estimators=200;, score=(train=0.345, test=0.103) total time=   1.9s
# [CV 1/5; 24/64] START max_depth=7, max_features=3, n_estimators=400.............
# [CV 1/5; 24/64] END max_depth=7, max_features=3, n_estimators=400;, score=(train=0.390, test=-2.684) total time=   3.8s
# [CV 2/5; 26/64] START max_depth=7, max_features=5, n_estimators=200.............
# [CV 2/5; 26/64] END max_depth=7, max_features=5, n_estimators=200;, score=(train=0.751, test=-0.090) total time=   2.0s
# [CV 4/5; 27/64] START max_depth=7, max_features=5, n_estimators=300.............
# [CV 4/5; 27/64] END max_depth=7, max_features=5, n_estimators=300;, score=(train=0.350, test=0.105) total time=   2.9s
# [CV 2/5; 29/64] START max_depth=7, max_features=7, n_estimators=100.............
# [CV 2/5; 29/64] END max_depth=7, max_features=7, n_estimators=100;, score=(train=0.755, test=-0.098) total time=   1.0s
# [CV 5/5; 29/64] START max_depth=7, max_features=7, n_estimators=100.............
# [CV 5/5; 29/64] END max_depth=7, max_features=7, n_estimators=100;, score=(train=0.491, test=-2.560) total time=   1.1s
# [CV 1/5; 31/64] START max_depth=7, max_features=7, n_estimators=300.............
# [CV 1/5; 31/64] END max_depth=7, max_features=7, n_estimators=300;, score=(train=0.389, test=-2.479) total time=   3.0s
# [CV 4/5; 32/64] START max_depth=7, max_features=7, n_estimators=400.............
# [CV 4/5; 32/64] END max_depth=7, max_features=7, n_estimators=400;, score=(train=0.351, test=0.100) total time=   3.9s
# [CV 2/5; 35/64] START max_depth=8, max_features=1, n_estimators=300.............
# [CV 2/5; 35/64] END max_depth=8, max_features=1, n_estimators=300;, score=(train=0.767, test=-0.080) total time=   2.8s
# [CV 5/5; 36/64] START max_depth=8, max_features=1, n_estimators=400.............
# [CV 5/5; 36/64] END max_depth=8, max_features=1, n_estimators=400;, score=(train=0.524, test=-3.612) total time=   3.8s
# [CV 1/5; 40/64] START max_depth=8, max_features=3, n_estimators=400.............
# [CV 1/5; 40/64] END max_depth=8, max_features=3, n_estimators=400;, score=(train=0.393, test=-2.734) total time=   3.8s
# [CV 2/5; 42/64] START max_depth=8, max_features=5, n_estimators=200.............
# [CV 2/5; 42/64] END max_depth=8, max_features=5, n_estimators=200;, score=(train=0.762, test=-0.089) total time=   2.1s
# [CV 4/5; 43/64] START max_depth=8, max_features=5, n_estimators=300.............
# [CV 4/5; 43/64] END max_depth=8, max_features=5, n_estimators=300;, score=(train=0.351, test=0.110) total time=   3.0s
# [CV 2/5; 45/64] START max_depth=8, max_features=7, n_estimators=100.............
# [CV 2/5; 45/64] END max_depth=8, max_features=7, n_estimators=100;, score=(train=0.759, test=-0.095) total time=   1.2s
# [CV 5/5; 45/64] START max_depth=8, max_features=7, n_estimators=100.............
# [CV 5/5; 45/64] END max_depth=8, max_features=7, n_estimators=100;, score=(train=0.497, test=-2.551) total time=   1.2s
# [CV 1/5; 47/64] START max_depth=8, max_features=7, n_estimators=300.............
# [CV 1/5; 47/64] END max_depth=8, max_features=7, n_estimators=300;, score=(train=0.388, test=-2.310) total time=   2.4s
# [CV 4/5; 48/64] START max_depth=8, max_features=7, n_estimators=400.............
# [CV 4/5; 48/64] END max_depth=8, max_features=7, n_estimators=400;, score=(train=0.352, test=0.104) total time=   3.3s
# [CV 3/5; 51/64] START max_depth=9, max_features=1, n_estimators=300.............
# [CV 3/5; 51/64] END max_depth=9, max_features=1, n_estimators=300;, score=(train=0.525, test=-4.594) total time=   2.5s
# [CV 2/5; 53/64] START max_depth=9, max_features=3, n_estimators=100.............
# [CV 2/5; 53/64] END max_depth=9, max_features=3, n_estimators=100;, score=(train=0.758, test=-0.092) total time=   1.1s
# [CV 1/5; 54/64] START max_depth=9, max_features=3, n_estimators=200.............
# [CV 1/5; 54/64] END max_depth=9, max_features=3, n_estimators=200;, score=(train=0.392, test=-2.521) total time=   1.8s
# [CV 2/5; 55/64] START max_depth=9, max_features=3, n_estimators=300.............
# [CV 2/5; 55/64] END max_depth=9, max_features=3, n_estimators=300;, score=(train=0.762, test=-0.088) total time=   2.7s
# [CV 1/5; 57/64] START max_depth=9, max_features=5, n_estimators=100.............
# [CV 1/5; 57/64] END max_depth=9, max_features=5, n_estimators=100;, score=(train=0.390, test=-1.816) total time=   0.7s
# [CV 4/5; 57/64] START max_depth=9, max_features=5, n_estimators=100.............
# [CV 4/5; 57/64] END max_depth=9, max_features=5, n_estimators=100;, score=(train=0.332, test=0.120) total time=   0.7s
# [CV 5/5; 58/64] START max_depth=9, max_features=5, n_estimators=200.............
# [CV 5/5; 58/64] END max_depth=9, max_features=5, n_estimators=200;, score=(train=0.517, test=-3.296) total time=   1.3s
# [CV 2/5; 60/64] START max_depth=9, max_features=5, n_estimators=400.............
# [CV 2/5; 60/64] END max_depth=9, max_features=5, n_estimators=400;, score=(train=0.757, test=-0.090) total time=   2.5s
# [CV 5/5; 61/64] START max_depth=9, max_features=7, n_estimators=100.............
# [CV 5/5; 61/64] END max_depth=9, max_features=7, n_estimators=100;, score=(train=0.498, test=-2.573) total time=   0.3s
# [CV 5/5; 62/64] START max_depth=9, max_features=7, n_estimators=200.............
# [CV 5/5; 62/64] END max_depth=9, max_features=7, n_estimators=200;, score=(train=0.518, test=-3.301) total time=   0.7s
# [CV 5/5; 63/64] START max_depth=9, max_features=7, n_estimators=300.............
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:926: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# RandomizedSearchCV(cv=5, error_score=0,
#                    estimator=RandomForestRegressor(random_state=66), n_iter=200,
#                    n_jobs=-1,
#                    param_distributions={'max_depth': [6, 7, 8, 9],
#                                         'max_features': [1, 3, 5, 7],
#                                         'n_estimators': [100, 200, 300, 400]},
#                    random_state=66, return_train_score=True, verbose=10)

# %%
RF_model_Capacity =RandomForestRegressor(n_estimators=666,min_samples_split=5,
             max_depth=7,min_samples_leaf=1,random_state = 66)

train_results =[]
train_results_name =['Experimental','Predicted','RMSE']


for train_index, test_index in kf.split(X_train):
    #print("Train:", train_index, "Validation:", test_index)
    X_training, X_validate = X_train.iloc[train_index], X_train.iloc[test_index]
    y_training, y_validate = y_train.iloc[train_index], y_train.iloc[test_index]
    
    np.random.seed(66)
    RF_model_Capacity.fit(X_training,y_training)
    y_train_predicted = RF_model_Capacity.predict(X_validate)
#     number_validate =X_validate.shape[0]
    mse = mean_squared_error(y_train_predicted, y_validate)
    RMSE = np.sqrt(mse)
#     Y_train_predicted = y_train_predicted.reshape(24,1)
#     print(y_train_predicted.shape)
#     squared_deviations = (y_train_predicted.reshape(24,1) - y_validate)**2
#     RMSE=math.sqrt(squared_deviations.sum()/number_validate)
    train_results.append([y_validate,y_train_predicted,RMSE])
# Out:
# /tmp/ipykernel_3819/445779285.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model_Capacity.fit(X_training,y_training)
# /tmp/ipykernel_3819/445779285.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model_Capacity.fit(X_training,y_training)
# /tmp/ipykernel_3819/445779285.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model_Capacity.fit(X_training,y_training)
# /tmp/ipykernel_3819/445779285.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model_Capacity.fit(X_training,y_training)
# /tmp/ipykernel_3819/445779285.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model_Capacity.fit(X_training,y_training)
# /tmp/ipykernel_3819/445779285.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model_Capacity.fit(X_training,y_training)
# /tmp/ipykernel_3819/445779285.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model_Capacity.fit(X_training,y_training)
# /tmp/ipykernel_3819/445779285.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model_Capacity.fit(X_training,y_training)
# /tmp/ipykernel_3819/445779285.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model_Capacity.fit(X_training,y_training)
# /tmp/ipykernel_3819/445779285.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model_Capacity.fit(X_training,y_training)

# %%
Train_results = pd.DataFrame (train_results,columns=train_results_name)

predict_results = pd.DataFrame (Train_results.iloc[:,1])

np.average(Train_results['RMSE'])
# Out:
# 0.6443715074856807

# %%
np.random.seed(66)
RF_model_Capacity.fit(X_train,y_train)
y_predict = RF_model_Capacity.predict(X_test)
#math.sqrt(stcs.mean((y_predict.reshape(80,1)-y_test)**2))

mse = mean_squared_error(y_predict, y_test)
RMSE = np.sqrt(mse)
RMSE
# number_test =X_test.shape[0]
# squared_deviations=(y_predict.reshape(80,1)-y_test)**2
# math.sqrt(squared_deviations.sum()/number_test)
# Out:
# /tmp/ipykernel_3819/3897174089.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model_Capacity.fit(X_train,y_train)
# 1.3624808017538492

# %%
"""
total = sum((y_test-stcs.mean(y_test))**2)
unexplained = sum((y_test-y_predict)**2)

R_square_test = 1-(unexplained/total)
"""
# Out:
# '\ntotal = sum((y_test-stcs.mean(y_test))**2)\nunexplained = sum((y_test-y_predict)**2)\n\nR_square_test = 1-(unexplained/total)\n'

# %%
"""
R_square_test
"""
# Out:
# '\nR_square_test\n'
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [CV 3/5; 59/64] END max_depth=9, max_features=5, n_estimators=300;, score=(train=0.525, test=-4.534) total time=   2.1s
# [CV 1/5; 61/64] START max_depth=9, max_features=7, n_estimators=100.............
# [CV 1/5; 61/64] END max_depth=9, max_features=7, n_estimators=100;, score=(train=0.389, test=-1.731) total time=   0.7s
# [CV 1/5; 62/64] START max_depth=9, max_features=7, n_estimators=200.............
# [CV 1/5; 62/64] END max_depth=9, max_features=7, n_estimators=200;, score=(train=0.390, test=-1.576) total time=   0.9s
# [CV 3/5; 63/64] START max_depth=9, max_features=7, n_estimators=300.............
# [CV 3/5; 63/64] END max_depth=9, max_features=7, n_estimators=300;, score=(train=0.521, test=-4.492) total time=   1.2s
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [CV 2/5; 2/64] START max_depth=6, max_features=1, n_estimators=200..............
# [CV 2/5; 2/64] END max_depth=6, max_features=1, n_estimators=200;, score=(train=0.739, test=-0.073) total time=   2.1s
# [CV 4/5; 3/64] START max_depth=6, max_features=1, n_estimators=300..............
# [CV 4/5; 3/64] END max_depth=6, max_features=1, n_estimators=300;, score=(train=0.339, test=0.089) total time=   3.0s
# [CV 2/5; 5/64] START max_depth=6, max_features=3, n_estimators=100..............
# [CV 2/5; 5/64] END max_depth=6, max_features=3, n_estimators=100;, score=(train=0.736, test=-0.088) total time=   1.0s
# [CV 5/5; 5/64] START max_depth=6, max_features=3, n_estimators=100..............
# [CV 5/5; 5/64] END max_depth=6, max_features=3, n_estimators=100;, score=(train=0.474, test=-2.326) total time=   1.2s
# [CV 1/5; 7/64] START max_depth=6, max_features=3, n_estimators=300..............
# [CV 1/5; 7/64] END max_depth=6, max_features=3, n_estimators=300;, score=(train=0.380, test=-3.012) total time=   3.3s
# [CV 4/5; 8/64] START max_depth=6, max_features=3, n_estimators=400..............
# [CV 4/5; 8/64] END max_depth=6, max_features=3, n_estimators=400;, score=(train=0.347, test=0.094) total time=   4.5s
# [CV 1/5; 11/64] START max_depth=6, max_features=5, n_estimators=300.............
# [CV 1/5; 11/64] END max_depth=6, max_features=5, n_estimators=300;, score=(train=0.380, test=-2.504) total time=   3.0s
# [CV 4/5; 12/64] START max_depth=6, max_features=5, n_estimators=400.............
# [CV 4/5; 12/64] END max_depth=6, max_features=5, n_estimators=400;, score=(train=0.349, test=0.087) total time=   3.9s
# [CV 2/5; 15/64] START max_depth=6, max_features=7, n_estimators=300.............
# [CV 2/5; 15/64] END max_depth=6, max_features=7, n_estimators=300;, score=(train=0.738, test=-0.091) total time=   2.9s
# [CV 5/5; 16/64] START max_depth=6, max_features=7, n_estimators=400.............
# [CV 5/5; 16/64] END max_depth=6, max_features=7, n_estimators=400;, score=(train=0.514, test=-3.597) total time=   3.8s
# [CV 4/5; 19/64] START max_depth=7, max_features=1, n_estimators=300.............
# [CV 4/5; 19/64] END max_depth=7, max_features=1, n_estimators=300;, score=(train=0.349, test=0.113) total time=   2.9s
# [CV 3/5; 21/64] START max_depth=7, max_features=3, n_estimators=100.............
# [CV 3/5; 21/64] END max_depth=7, max_features=3, n_estimators=100;, score=(train=0.488, test=-3.021) total time=   1.0s
# [CV 2/5; 22/64] START max_depth=7, max_features=3, n_estimators=200.............
# [CV 2/5; 22/64] END max_depth=7, max_features=3, n_estimators=200;, score=(train=0.753, test=-0.085) total time=   1.9s
# [CV 4/5; 23/64] START max_depth=7, max_features=3, n_estimators=300.............
# [CV 4/5; 23/64] END max_depth=7, max_features=3, n_estimators=300;, score=(train=0.349, test=0.105) total time=   2.9s
# [CV 2/5; 25/64] START max_depth=7, max_features=5, n_estimators=100.............
# [CV 2/5; 25/64] END max_depth=7, max_features=5, n_estimators=100;, score=(train=0.751, test=-0.084) total time=   1.0s
# [CV 5/5; 25/64] START max_depth=7, max_features=5, n_estimators=100.............
# [CV 5/5; 25/64] END max_depth=7, max_features=5, n_estimators=100;, score=(train=0.496, test=-2.562) total time=   1.0s
# [CV 1/5; 27/64] START max_depth=7, max_features=5, n_estimators=300.............
# [CV 1/5; 27/64] END max_depth=7, max_features=5, n_estimators=300;, score=(train=0.387, test=-2.944) total time=   2.9s
# [CV 4/5; 28/64] START max_depth=7, max_features=5, n_estimators=400.............
# [CV 4/5; 28/64] END max_depth=7, max_features=5, n_estimators=400;, score=(train=0.351, test=0.101) total time=   4.0s
# [CV 2/5; 31/64] START max_depth=7, max_features=7, n_estimators=300.............
# [CV 2/5; 31/64] END max_depth=7, max_features=7, n_estimators=300;, score=(train=0.752, test=-0.095) total time=   3.0s
# [CV 5/5; 32/64] START max_depth=7, max_features=7, n_estimators=400.............
# [CV 5/5; 32/64] END max_depth=7, max_features=7, n_estimators=400;, score=(train=0.518, test=-3.607) total time=   3.9s
# [CV 1/5; 36/64] START max_depth=8, max_features=1, n_estimators=400.............
# [CV 1/5; 36/64] END max_depth=8, max_features=1, n_estimators=400;, score=(train=0.393, test=-1.982) total time=   3.8s
# [CV 3/5; 38/64] START max_depth=8, max_features=3, n_estimators=200.............
# [CV 3/5; 38/64] END max_depth=8, max_features=3, n_estimators=200;, score=(train=0.518, test=-4.137) total time=   2.0s
# [CV 5/5; 39/64] START max_depth=8, max_features=3, n_estimators=300.............
# [CV 5/5; 39/64] END max_depth=8, max_features=3, n_estimators=300;, score=(train=0.521, test=-3.428) total time=   2.9s
# [CV 3/5; 41/64] START max_depth=8, max_features=5, n_estimators=100.............
# [CV 3/5; 41/64] END max_depth=8, max_features=5, n_estimators=100;, score=(train=0.493, test=-3.004) total time=   1.0s
# [CV 1/5; 42/64] START max_depth=8, max_features=5, n_estimators=200.............
# [CV 1/5; 42/64] END max_depth=8, max_features=5, n_estimators=200;, score=(train=0.390, test=-2.384) total time=   2.1s
# [CV 3/5; 43/64] START max_depth=8, max_features=5, n_estimators=300.............
# [CV 3/5; 43/64] END max_depth=8, max_features=5, n_estimators=300;, score=(train=0.524, test=-4.543) total time=   2.9s
# [CV 1/5; 45/64] START max_depth=8, max_features=7, n_estimators=100.............
# [CV 1/5; 45/64] END max_depth=8, max_features=7, n_estimators=100;, score=(train=0.388, test=-2.051) total time=   1.2s
# [CV 4/5; 45/64] START max_depth=8, max_features=7, n_estimators=100.............
# [CV 4/5; 45/64] END max_depth=8, max_features=7, n_estimators=100;, score=(train=0.331, test=0.089) total time=   1.2s
# [CV 5/5; 46/64] START max_depth=8, max_features=7, n_estimators=200.............
# [CV 5/5; 46/64] END max_depth=8, max_features=7, n_estimators=200;, score=(train=0.519, test=-3.279) total time=   1.7s
# [CV 3/5; 48/64] START max_depth=8, max_features=7, n_estimators=400.............
# [CV 3/5; 48/64] END max_depth=8, max_features=7, n_estimators=400;, score=(train=0.521, test=-4.544) total time=   3.2s
# [CV 4/5; 50/64] START max_depth=9, max_features=1, n_estimators=200.............
# [CV 4/5; 50/64] END max_depth=9, max_features=1, n_estimators=200;, score=(train=0.348, test=0.136) total time=   2.2s
# [CV 3/5; 52/64] START max_depth=9, max_features=1, n_estimators=400.............
# [CV 3/5; 52/64] END max_depth=9, max_features=1, n_estimators=400;, score=(train=0.524, test=-4.602) total time=   4.0s
# [CV 1/5; 55/64] START max_depth=9, max_features=3, n_estimators=300.............
# [CV 1/5; 55/64] END max_depth=9, max_features=3, n_estimators=300;, score=(train=0.391, test=-2.637) total time=   3.1s
# [CV 4/5; 56/64] START max_depth=9, max_features=3, n_estimators=400.............
# [CV 4/5; 56/64] END max_depth=9, max_features=3, n_estimators=400;, score=(train=0.353, test=0.122) total time=   2.9s
# [CV 5/5; 59/64] START max_depth=9, max_features=5, n_estimators=300.............
# [CV 5/5; 59/64] END max_depth=9, max_features=5, n_estimators=300;, score=(train=0.520, test=-3.421) total time=   2.1s
# [CV 2/5; 61/64] START max_depth=9, max_features=7, n_estimators=100.............
# [CV 2/5; 61/64] END max_depth=9, max_features=7, n_estimators=100;, score=(train=0.757, test=-0.092) total time=   0.7s
# [CV 2/5; 62/64] START max_depth=9, max_features=7, n_estimators=200.............
# [CV 2/5; 62/64] END max_depth=9, max_features=7, n_estimators=200;, score=(train=0.760, test=-0.093) total time=   0.8s
# [CV 4/5; 63/64] START max_depth=9, max_features=7, n_estimators=300.............
# [CV 4/5; 63/64] END max_depth=9, max_features=7, n_estimators=300;, score=(train=0.352, test=0.126) total time=   1.3s
# [CV 5/5; 63/64] END max_depth=9, max_features=7, n_estimators=300;, score=(train=0.520, test=-3.425) total time=   1.4s
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [CV 1/5; 2/64] START max_depth=6, max_features=1, n_estimators=200..............
# [CV 1/5; 2/64] END max_depth=6, max_features=1, n_estimators=200;, score=(train=0.370, test=-1.492) total time=   2.1s
# [CV 5/5; 3/64] START max_depth=6, max_features=1, n_estimators=300..............
# [CV 5/5; 3/64] END max_depth=6, max_features=1, n_estimators=300;, score=(train=0.481, test=-2.635) total time=   3.1s
# [CV 3/5; 5/64] START max_depth=6, max_features=3, n_estimators=100..............
# [CV 3/5; 5/64] END max_depth=6, max_features=3, n_estimators=100;, score=(train=0.457, test=-2.370) total time=   1.0s
# [CV 1/5; 6/64] START max_depth=6, max_features=3, n_estimators=200..............
# [CV 1/5; 6/64] END max_depth=6, max_features=3, n_estimators=200;, score=(train=0.380, test=-2.948) total time=   2.7s
# [CV 4/5; 7/64] START max_depth=6, max_features=3, n_estimators=300..............
# [CV 4/5; 7/64] END max_depth=6, max_features=3, n_estimators=300;, score=(train=0.346, test=0.085) total time=   4.1s
# [CV 3/5; 9/64] START max_depth=6, max_features=5, n_estimators=100..............
# [CV 3/5; 9/64] END max_depth=6, max_features=5, n_estimators=100;, score=(train=0.483, test=-2.989) total time=   1.4s
# [CV 2/5; 10/64] START max_depth=6, max_features=5, n_estimators=200.............
# [CV 2/5; 10/64] END max_depth=6, max_features=5, n_estimators=200;, score=(train=0.731, test=-0.082) total time=   2.1s
# [CV 5/5; 11/64] START max_depth=6, max_features=5, n_estimators=300.............
# [CV 5/5; 11/64] END max_depth=6, max_features=5, n_estimators=300;, score=(train=0.509, test=-3.407) total time=   3.1s
# [CV 3/5; 13/64] START max_depth=6, max_features=7, n_estimators=100.............
# [CV 3/5; 13/64] END max_depth=6, max_features=7, n_estimators=100;, score=(train=0.484, test=-2.937) total time=   1.0s
# [CV 3/5; 14/64] START max_depth=6, max_features=7, n_estimators=200.............
# [CV 3/5; 14/64] END max_depth=6, max_features=7, n_estimators=200;, score=(train=0.509, test=-4.101) total time=   2.0s
# [CV 1/5; 16/64] START max_depth=6, max_features=7, n_estimators=400.............
# [CV 1/5; 16/64] END max_depth=6, max_features=7, n_estimators=400;, score=(train=0.384, test=-2.322) total time=   3.9s
# [CV 2/5; 18/64] START max_depth=7, max_features=1, n_estimators=200.............
# [CV 2/5; 18/64] END max_depth=7, max_features=1, n_estimators=200;, score=(train=0.760, test=-0.082) total time=   1.9s
# [CV 1/5; 20/64] START max_depth=7, max_features=1, n_estimators=400.............
# [CV 1/5; 20/64] END max_depth=7, max_features=1, n_estimators=400;, score=(train=0.389, test=-2.030) total time=   3.8s
# [CV 4/5; 21/64] START max_depth=7, max_features=3, n_estimators=100.............
# [CV 4/5; 21/64] END max_depth=7, max_features=3, n_estimators=100;, score=(train=0.327, test=0.102) total time=   1.0s
# [CV 1/5; 23/64] START max_depth=7, max_features=3, n_estimators=300.............
# [CV 1/5; 23/64] END max_depth=7, max_features=3, n_estimators=300;, score=(train=0.389, test=-2.749) total time=   3.0s
# [CV 4/5; 24/64] START max_depth=7, max_features=3, n_estimators=400.............
# [CV 4/5; 24/64] END max_depth=7, max_features=3, n_estimators=400;, score=(train=0.350, test=0.108) total time=   3.8s
# [CV 2/5; 27/64] START max_depth=7, max_features=5, n_estimators=300.............
# [CV 2/5; 27/64] END max_depth=7, max_features=5, n_estimators=300;, score=(train=0.752, test=-0.086) total time=   2.9s
# [CV 5/5; 28/64] START max_depth=7, max_features=5, n_estimators=400.............
# [CV 5/5; 28/64] END max_depth=7, max_features=5, n_estimators=400;, score=(train=0.520, test=-3.600) total time=   4.0s
# [CV 5/5; 31/64] START max_depth=7, max_features=7, n_estimators=300.............
# [CV 5/5; 31/64] END max_depth=7, max_features=7, n_estimators=300;, score=(train=0.516, test=-3.415) total time=   2.9s
# [CV 3/5; 33/64] START max_depth=8, max_features=1, n_estimators=100.............
# [CV 3/5; 33/64] END max_depth=8, max_features=1, n_estimators=100;, score=(train=0.492, test=-3.131) total time=   1.0s
# [CV 2/5; 34/64] START max_depth=8, max_features=1, n_estimators=200.............
# [CV 2/5; 34/64] END max_depth=8, max_features=1, n_estimators=200;, score=(train=0.767, test=-0.082) total time=   1.9s
# [CV 4/5; 35/64] START max_depth=8, max_features=1, n_estimators=300.............
# [CV 4/5; 35/64] END max_depth=8, max_features=1, n_estimators=300;, score=(train=0.351, test=0.117) total time=   2.9s
# [CV 2/5; 37/64] START max_depth=8, max_features=3, n_estimators=100.............
# [CV 2/5; 37/64] END max_depth=8, max_features=3, n_estimators=100;, score=(train=0.760, test=-0.086) total time=   1.0s
# [CV 4/5; 37/64] START max_depth=8, max_features=3, n_estimators=100.............
# [CV 4/5; 37/64] END max_depth=8, max_features=3, n_estimators=100;, score=(train=0.330, test=0.136) total time=   1.0s
# [CV 5/5; 38/64] START max_depth=8, max_features=3, n_estimators=200.............
# [CV 5/5; 38/64] END max_depth=8, max_features=3, n_estimators=200;, score=(train=0.518, test=-3.306) total time=   2.0s
# [CV 3/5; 40/64] START max_depth=8, max_features=3, n_estimators=400.............
# [CV 3/5; 40/64] END max_depth=8, max_features=3, n_estimators=400;, score=(train=0.522, test=-4.538) total time=   3.9s
# [CV 4/5; 42/64] START max_depth=8, max_features=5, n_estimators=200.............
# [CV 4/5; 42/64] END max_depth=8, max_features=5, n_estimators=200;, score=(train=0.348, test=0.110) total time=   2.0s
# [CV 3/5; 44/64] START max_depth=8, max_features=5, n_estimators=400.............
# [CV 3/5; 44/64] END max_depth=8, max_features=5, n_estimators=400;, score=(train=0.523, test=-4.556) total time=   4.0s
# [CV 4/5; 46/64] START max_depth=8, max_features=7, n_estimators=200.............
# [CV 4/5; 46/64] END max_depth=8, max_features=7, n_estimators=200;, score=(train=0.347, test=0.105) total time=   1.8s
# [CV 1/5; 48/64] START max_depth=8, max_features=7, n_estimators=400.............
# [CV 1/5; 48/64] END max_depth=8, max_features=7, n_estimators=400;, score=(train=0.389, test=-2.157) total time=   3.2s
# [CV 1/5; 50/64] START max_depth=9, max_features=1, n_estimators=200.............
# [CV 1/5; 50/64] END max_depth=9, max_features=1, n_estimators=200;, score=(train=0.393, test=-1.704) total time=   1.7s
# [CV 4/5; 51/64] START max_depth=9, max_features=1, n_estimators=300.............
# [CV 4/5; 51/64] END max_depth=9, max_features=1, n_estimators=300;, score=(train=0.352, test=0.128) total time=   2.2s
# [CV 1/5; 53/64] START max_depth=9, max_features=3, n_estimators=100.............
# [CV 1/5; 53/64] END max_depth=9, max_features=3, n_estimators=100;, score=(train=0.394, test=-2.638) total time=   0.8s
# [CV 4/5; 53/64] START max_depth=9, max_features=3, n_estimators=100.............
# [CV 4/5; 53/64] END max_depth=9, max_features=3, n_estimators=100;, score=(train=0.331, test=0.117) total time=   1.1s
# [CV 5/5; 54/64] START max_depth=9, max_features=3, n_estimators=200.............
# [CV 5/5; 54/64] END max_depth=9, max_features=3, n_estimators=200;, score=(train=0.520, test=-3.303) total time=   2.0s
# [CV 3/5; 56/64] START max_depth=9, max_features=3, n_estimators=400.............
# [CV 3/5; 56/64] END max_depth=9, max_features=3, n_estimators=400;, score=(train=0.524, test=-4.565) total time=   3.0s
# [CV 1/5; 58/64] START max_depth=9, max_features=5, n_estimators=200.............
# [CV 1/5; 58/64] END max_depth=9, max_features=5, n_estimators=200;, score=(train=0.390, test=-2.286) total time=   1.3s
# [CV 2/5; 59/64] START max_depth=9, max_features=5, n_estimators=300.............
# [CV 2/5; 59/64] END max_depth=9, max_features=5, n_estimators=300;, score=(train=0.761, test=-0.093) total time=   2.2s
# [CV 5/5; 60/64] START max_depth=9, max_features=5, n_estimators=400.............
# [CV 5/5; 60/64] END max_depth=9, max_features=5, n_estimators=400;, score=(train=0.523, test=-3.610) total time=   1.9s
# [CV 1/5; 64/64] START max_depth=9, max_features=7, n_estimators=400.............
# [CV 1/5; 64/64] END max_depth=9, max_features=7, n_estimators=400;, score=(train=0.390, test=-2.053) total time=   1.5s
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [CV 3/5; 1/64] START max_depth=6, max_features=1, n_estimators=100..............
# [CV 3/5; 1/64] END max_depth=6, max_features=1, n_estimators=100;, score=(train=0.471, test=-2.697) total time=   1.1s
# [CV 4/5; 2/64] START max_depth=6, max_features=1, n_estimators=200..............
# [CV 4/5; 2/64] END max_depth=6, max_features=1, n_estimators=200;, score=(train=0.333, test=0.091) total time=   2.0s
# [CV 2/5; 4/64] START max_depth=6, max_features=1, n_estimators=400..............
# [CV 2/5; 4/64] END max_depth=6, max_features=1, n_estimators=400;, score=(train=0.734, test=-0.074) total time=   4.0s
# [CV 5/5; 6/64] START max_depth=6, max_features=3, n_estimators=200..............
# [CV 5/5; 6/64] END max_depth=6, max_features=3, n_estimators=200;, score=(train=0.498, test=-3.115) total time=   2.3s
# [CV 1/5; 8/64] START max_depth=6, max_features=3, n_estimators=400..............
# [CV 1/5; 8/64] END max_depth=6, max_features=3, n_estimators=400;, score=(train=0.380, test=-2.820) total time=   4.6s
# [CV 4/5; 9/64] START max_depth=6, max_features=5, n_estimators=100..............
# [CV 4/5; 9/64] END max_depth=6, max_features=5, n_estimators=100;, score=(train=0.328, test=0.095) total time=   1.1s
# [CV 5/5; 10/64] START max_depth=6, max_features=5, n_estimators=200.............
# [CV 5/5; 10/64] END max_depth=6, max_features=5, n_estimators=200;, score=(train=0.506, test=-3.313) total time=   2.0s
# [CV 3/5; 12/64] START max_depth=6, max_features=5, n_estimators=400.............
# [CV 3/5; 12/64] END max_depth=6, max_features=5, n_estimators=400;, score=(train=0.512, test=-4.443) total time=   3.9s
# [CV 1/5; 14/64] START max_depth=6, max_features=7, n_estimators=200.............
# [CV 1/5; 14/64] END max_depth=6, max_features=7, n_estimators=200;, score=(train=0.382, test=-1.715) total time=   2.0s
# [CV 4/5; 15/64] START max_depth=6, max_features=7, n_estimators=300.............
# [CV 4/5; 15/64] END max_depth=6, max_features=7, n_estimators=300;, score=(train=0.348, test=0.082) total time=   2.9s
# [CV 2/5; 17/64] START max_depth=7, max_features=1, n_estimators=100.............
# [CV 2/5; 17/64] END max_depth=7, max_features=1, n_estimators=100;, score=(train=0.757, test=-0.080) total time=   0.9s
# [CV 5/5; 17/64] START max_depth=7, max_features=1, n_estimators=100.............
# [CV 5/5; 17/64] END max_depth=7, max_features=1, n_estimators=100;, score=(train=0.487, test=-2.360) total time=   0.9s
# [CV 1/5; 19/64] START max_depth=7, max_features=1, n_estimators=300.............
# [CV 1/5; 19/64] END max_depth=7, max_features=1, n_estimators=300;, score=(train=0.388, test=-1.995) total time=   2.8s
# [CV 4/5; 20/64] START max_depth=7, max_features=1, n_estimators=400.............
# [CV 4/5; 20/64] END max_depth=7, max_features=1, n_estimators=400;, score=(train=0.350, test=0.113) total time=   3.8s
# [CV 2/5; 23/64] START max_depth=7, max_features=3, n_estimators=300.............
# [CV 2/5; 23/64] END max_depth=7, max_features=3, n_estimators=300;, score=(train=0.756, test=-0.081) total time=   2.9s
# [CV 5/5; 24/64] START max_depth=7, max_features=3, n_estimators=400.............
# [CV 5/5; 24/64] END max_depth=7, max_features=3, n_estimators=400;, score=(train=0.519, test=-3.610) total time=   3.8s
# [CV 1/5; 28/64] START max_depth=7, max_features=5, n_estimators=400.............
# [CV 1/5; 28/64] END max_depth=7, max_features=5, n_estimators=400;, score=(train=0.388, test=-2.899) total time=   3.9s
# [CV 1/5; 30/64] START max_depth=7, max_features=7, n_estimators=200.............
# [CV 1/5; 30/64] END max_depth=7, max_features=7, n_estimators=200;, score=(train=0.388, test=-1.920) total time=   2.1s
# [CV 3/5; 31/64] START max_depth=7, max_features=7, n_estimators=300.............
# [CV 3/5; 31/64] END max_depth=7, max_features=7, n_estimators=300;, score=(train=0.521, test=-4.498) total time=   2.9s
# [CV 1/5; 33/64] START max_depth=8, max_features=1, n_estimators=100.............
# [CV 1/5; 33/64] END max_depth=8, max_features=1, n_estimators=100;, score=(train=0.395, test=-1.766) total time=   1.0s
# [CV 4/5; 33/64] START max_depth=8, max_features=1, n_estimators=100.............
# [CV 4/5; 33/64] END max_depth=8, max_features=1, n_estimators=100;, score=(train=0.331, test=0.123) total time=   1.0s
# [CV 1/5; 35/64] START max_depth=8, max_features=1, n_estimators=300.............
# [CV 1/5; 35/64] END max_depth=8, max_features=1, n_estimators=300;, score=(train=0.392, test=-1.960) total time=   2.8s
# [CV 4/5; 36/64] START max_depth=8, max_features=1, n_estimators=400.............
# [CV 4/5; 36/64] END max_depth=8, max_features=1, n_estimators=400;, score=(train=0.352, test=0.125) total time=   3.8s
# [CV 2/5; 39/64] START max_depth=8, max_features=3, n_estimators=300.............
# [CV 2/5; 39/64] END max_depth=8, max_features=3, n_estimators=300;, score=(train=0.759, test=-0.087) total time=   2.9s
# [CV 5/5; 40/64] START max_depth=8, max_features=3, n_estimators=400.............
# [CV 5/5; 40/64] END max_depth=8, max_features=3, n_estimators=400;, score=(train=0.523, test=-3.620) total time=   4.0s
# [CV 5/5; 43/64] START max_depth=8, max_features=5, n_estimators=300.............
# [CV 5/5; 43/64] END max_depth=8, max_features=5, n_estimators=300;, score=(train=0.520, test=-3.424) total time=   2.9s
# [CV 3/5; 45/64] START max_depth=8, max_features=7, n_estimators=100.............
# [CV 3/5; 45/64] END max_depth=8, max_features=7, n_estimators=100;, score=(train=0.492, test=-2.978) total time=   1.1s
# [CV 1/5; 46/64] START max_depth=8, max_features=7, n_estimators=200.............
# [CV 1/5; 46/64] END max_depth=8, max_features=7, n_estimators=200;, score=(train=0.388, test=-1.992) total time=   2.0s
# [CV 3/5; 47/64] START max_depth=8, max_features=7, n_estimators=300.............
# [CV 3/5; 47/64] END max_depth=8, max_features=7, n_estimators=300;, score=(train=0.522, test=-4.521) total time=   2.4s
# [CV 1/5; 49/64] START max_depth=9, max_features=1, n_estimators=100.............
# [CV 1/5; 49/64] END max_depth=9, max_features=1, n_estimators=100;, score=(train=0.396, test=-1.601) total time=   0.9s
# [CV 5/5; 49/64] START max_depth=9, max_features=1, n_estimators=100.............
# [CV 5/5; 49/64] END max_depth=9, max_features=1, n_estimators=100;, score=(train=0.500, test=-2.580) total time=   1.1s
# [CV 1/5; 51/64] START max_depth=9, max_features=1, n_estimators=300.............
# [CV 1/5; 51/64] END max_depth=9, max_features=1, n_estimators=300;, score=(train=0.393, test=-2.208) total time=   2.9s
# [CV 4/5; 52/64] START max_depth=9, max_features=1, n_estimators=400.............
# [CV 4/5; 52/64] END max_depth=9, max_features=1, n_estimators=400;, score=(train=0.353, test=0.133) total time=   4.1s
# [CV 2/5; 56/64] START max_depth=9, max_features=3, n_estimators=400.............
# [CV 2/5; 56/64] END max_depth=9, max_features=3, n_estimators=400;, score=(train=0.760, test=-0.086) total time=   3.3s
# [CV 4/5; 58/64] START max_depth=9, max_features=5, n_estimators=200.............
# [CV 4/5; 58/64] END max_depth=9, max_features=5, n_estimators=200;, score=(train=0.348, test=0.122) total time=   1.4s
# [CV 3/5; 60/64] START max_depth=9, max_features=5, n_estimators=400.............
# [CV 3/5; 60/64] END max_depth=9, max_features=5, n_estimators=400;, score=(train=0.524, test=-4.553) total time=   2.7s
# [CV 3/5; 62/64] START max_depth=9, max_features=7, n_estimators=200.............
# [CV 3/5; 62/64] END max_depth=9, max_features=7, n_estimators=200;, score=(train=0.516, test=-4.135) total time=   1.2s
# [CV 3/5; 64/64] START max_depth=9, max_features=7, n_estimators=400.............
# [CV 3/5; 64/64] END max_depth=9, max_features=7, n_estimators=400;, score=(train=0.520, test=-4.527) total time=   1.4s
# [CV 4/5; 1/64] START max_depth=6, max_features=1, n_estimators=100..............
# [CV 4/5; 1/64] END max_depth=6, max_features=1, n_estimators=100;, score=(train=0.312, test=0.092) total time=   1.0s
# [CV 2/5; 3/64] START max_depth=6, max_features=1, n_estimators=300..............
# ...
# [CV 4/5; 60/64] END max_depth=9, max_features=5, n_estimators=400;, score=(train=0.353, test=0.118) total time=   2.2s
# [CV 2/5; 63/64] START max_depth=9, max_features=7, n_estimators=300.............
# [CV 2/5; 63/64] END max_depth=9, max_features=7, n_estimators=300;, score=(train=0.761, test=-0.093) total time=   1.1s
# [CV 4/5; 64/64] START max_depth=9, max_features=7, n_estimators=400.............
# [CV 4/5; 64/64] END max_depth=9, max_features=7, n_estimators=400;, score=(train=0.353, test=0.123) total time=   1.3s
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [CV 5/5; 1/64] START max_depth=6, max_features=1, n_estimators=100..............
# [CV 5/5; 1/64] END max_depth=6, max_features=1, n_estimators=100;, score=(train=0.452, test=-1.882) total time=   1.1s
# [CV 3/5; 3/64] START max_depth=6, max_features=1, n_estimators=300..............
# [CV 3/5; 3/64] END max_depth=6, max_features=1, n_estimators=300;, score=(train=0.497, test=-3.706) total time=   3.2s
# [CV 1/5; 5/64] START max_depth=6, max_features=3, n_estimators=100..............
# [CV 1/5; 5/64] END max_depth=6, max_features=3, n_estimators=100;, score=(train=0.380, test=-2.827) total time=   1.1s
# [CV 4/5; 5/64] START max_depth=6, max_features=3, n_estimators=100..............
# [CV 4/5; 5/64] END max_depth=6, max_features=3, n_estimators=100;, score=(train=0.323, test=0.088) total time=   1.0s
# [CV 3/5; 6/64] START max_depth=6, max_features=3, n_estimators=200..............
# [CV 3/5; 6/64] END max_depth=6, max_features=3, n_estimators=200;, score=(train=0.498, test=-3.712) total time=   2.8s
# [CV 3/5; 8/64] START max_depth=6, max_features=3, n_estimators=400..............
# [CV 3/5; 8/64] END max_depth=6, max_features=3, n_estimators=400;, score=(train=0.505, test=-4.220) total time=   5.6s
# [CV 4/5; 10/64] START max_depth=6, max_features=5, n_estimators=200.............
# [CV 4/5; 10/64] END max_depth=6, max_features=5, n_estimators=200;, score=(train=0.344, test=0.086) total time=   2.1s
# [CV 2/5; 12/64] START max_depth=6, max_features=5, n_estimators=400.............
# [CV 2/5; 12/64] END max_depth=6, max_features=5, n_estimators=400;, score=(train=0.726, test=-0.080) total time=   4.1s
# [CV 4/5; 14/64] START max_depth=6, max_features=7, n_estimators=200.............
# [CV 4/5; 14/64] END max_depth=6, max_features=7, n_estimators=200;, score=(train=0.345, test=0.074) total time=   2.0s
# [CV 2/5; 16/64] START max_depth=6, max_features=7, n_estimators=400.............
# [CV 2/5; 16/64] END max_depth=6, max_features=7, n_estimators=400;, score=(train=0.734, test=-0.088) total time=   3.8s
# [CV 3/5; 18/64] START max_depth=7, max_features=1, n_estimators=200.............
# [CV 3/5; 18/64] END max_depth=7, max_features=1, n_estimators=200;, score=(train=0.513, test=-4.248) total time=   1.9s
# [CV 5/5; 19/64] START max_depth=7, max_features=1, n_estimators=300.............
# [CV 5/5; 19/64] END max_depth=7, max_features=1, n_estimators=300;, score=(train=0.513, test=-3.311) total time=   2.9s
# [CV 2/5; 21/64] START max_depth=7, max_features=3, n_estimators=100.............
# [CV 2/5; 21/64] END max_depth=7, max_features=3, n_estimators=100;, score=(train=0.760, test=-0.086) total time=   1.0s
# [CV 1/5; 22/64] START max_depth=7, max_features=3, n_estimators=200.............
# [CV 1/5; 22/64] END max_depth=7, max_features=3, n_estimators=200;, score=(train=0.389, test=-2.408) total time=   1.9s
# [CV 3/5; 23/64] START max_depth=7, max_features=3, n_estimators=300.............
# [CV 3/5; 23/64] END max_depth=7, max_features=3, n_estimators=300;, score=(train=0.520, test=-4.568) total time=   2.9s
# [CV 1/5; 25/64] START max_depth=7, max_features=5, n_estimators=100.............
# [CV 1/5; 25/64] END max_depth=7, max_features=5, n_estimators=100;, score=(train=0.390, test=-2.180) total time=   1.0s
# [CV 4/5; 25/64] START max_depth=7, max_features=5, n_estimators=100.............
# [CV 4/5; 25/64] END max_depth=7, max_features=5, n_estimators=100;, score=(train=0.330, test=0.113) total time=   1.0s
# [CV 5/5; 26/64] START max_depth=7, max_features=5, n_estimators=200.............
# [CV 5/5; 26/64] END max_depth=7, max_features=5, n_estimators=200;, score=(train=0.516, test=-3.289) total time=   1.9s
# [CV 3/5; 28/64] START max_depth=7, max_features=5, n_estimators=400.............
# [CV 3/5; 28/64] END max_depth=7, max_features=5, n_estimators=400;, score=(train=0.520, test=-4.515) total time=   3.8s
# [CV 4/5; 30/64] START max_depth=7, max_features=7, n_estimators=200.............
# [CV 4/5; 30/64] END max_depth=7, max_features=7, n_estimators=200;, score=(train=0.347, test=0.093) total time=   2.1s
# [CV 2/5; 32/64] START max_depth=7, max_features=7, n_estimators=400.............
# [CV 2/5; 32/64] END max_depth=7, max_features=7, n_estimators=400;, score=(train=0.750, test=-0.094) total time=   3.9s
# [CV 3/5; 34/64] START max_depth=8, max_features=1, n_estimators=200.............
# [CV 3/5; 34/64] END max_depth=8, max_features=1, n_estimators=200;, score=(train=0.519, test=-4.283) total time=   1.9s
# [CV 5/5; 35/64] START max_depth=8, max_features=1, n_estimators=300.............
# [CV 5/5; 35/64] END max_depth=8, max_features=1, n_estimators=300;, score=(train=0.520, test=-3.426) total time=   2.8s
# [CV 3/5; 37/64] START max_depth=8, max_features=3, n_estimators=100.............
# [CV 3/5; 37/64] END max_depth=8, max_features=3, n_estimators=100;, score=(train=0.494, test=-2.941) total time=   1.0s
# [CV 2/5; 38/64] START max_depth=8, max_features=3, n_estimators=200.............
# [CV 2/5; 38/64] END max_depth=8, max_features=3, n_estimators=200;, score=(train=0.763, test=-0.088) total time=   2.0s
# [CV 4/5; 39/64] START max_depth=8, max_features=3, n_estimators=300.............
# [CV 4/5; 39/64] END max_depth=8, max_features=3, n_estimators=300;, score=(train=0.351, test=0.124) total time=   2.9s
# [CV 2/5; 41/64] START max_depth=8, max_features=5, n_estimators=100.............
# [CV 2/5; 41/64] END max_depth=8, max_features=5, n_estimators=100;, score=(train=0.760, test=-0.083) total time=   1.0s
# [CV 5/5; 41/64] START max_depth=8, max_features=5, n_estimators=100.............
# [CV 5/5; 41/64] END max_depth=8, max_features=5, n_estimators=100;, score=(train=0.494, test=-2.582) total time=   1.2s
# [CV 1/5; 43/64] START max_depth=8, max_features=5, n_estimators=300.............
# [CV 1/5; 43/64] END max_depth=8, max_features=5, n_estimators=300;, score=(train=0.390, test=-3.130) total time=   3.0s
# [CV 4/5; 44/64] START max_depth=8, max_features=5, n_estimators=400.............
# [CV 4/5; 44/64] END max_depth=8, max_features=5, n_estimators=400;, score=(train=0.353, test=0.117) total time=   3.9s
# [CV 2/5; 47/64] START max_depth=8, max_features=7, n_estimators=300.............
# [CV 2/5; 47/64] END max_depth=8, max_features=7, n_estimators=300;, score=(train=0.759, test=-0.092) total time=   2.3s
# [CV 5/5; 48/64] START max_depth=8, max_features=7, n_estimators=400.............
# [CV 5/5; 48/64] END max_depth=8, max_features=7, n_estimators=400;, score=(train=0.523, test=-3.601) total time=   3.2s
# [CV 2/5; 51/64] START max_depth=9, max_features=1, n_estimators=300.............
# [CV 2/5; 51/64] END max_depth=9, max_features=1, n_estimators=300;, score=(train=0.768, test=-0.073) total time=   2.3s
# [CV 5/5; 52/64] START max_depth=9, max_features=1, n_estimators=400.............
# [CV 5/5; 52/64] END max_depth=9, max_features=1, n_estimators=400;, score=(train=0.525, test=-3.613) total time=   3.3s
# [CV 3/5; 55/64] START max_depth=9, max_features=3, n_estimators=300.............
# [CV 3/5; 55/64] END max_depth=9, max_features=3, n_estimators=300;, score=(train=0.523, test=-4.564) total time=   2.5s
# [CV 5/5; 56/64] START max_depth=9, max_features=3, n_estimators=400.............
# [CV 5/5; 56/64] END max_depth=9, max_features=3, n_estimators=400;, score=(train=0.524, test=-3.616) total time=   2.9s
# [CV 1/5; 60/64] START max_depth=9, max_features=5, n_estimators=400.............
# [CV 1/5; 60/64] END max_depth=9, max_features=5, n_estimators=400;, score=(train=0.391, test=-2.577) total time=   2.6s
# [CV 4/5; 61/64] START max_depth=9, max_features=7, n_estimators=100.............
# [CV 4/5; 61/64] END max_depth=9, max_features=7, n_estimators=100;, score=(train=0.332, test=0.132) total time=   0.5s
# [CV 1/5; 63/64] START max_depth=9, max_features=7, n_estimators=300.............
# [CV 1/5; 63/64] END max_depth=9, max_features=7, n_estimators=300;, score=(train=0.390, test=-2.086) total time=   1.2s
# [CV 5/5; 64/64] START max_depth=9, max_features=7, n_estimators=400.............
# [CV 5/5; 64/64] END max_depth=9, max_features=7, n_estimators=400;, score=(train=0.521, test=-3.617) total time=   1.3s
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
