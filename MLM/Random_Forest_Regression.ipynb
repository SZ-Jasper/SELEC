# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy 
import os
# import seaborn as sns
# import scipy.stats as stats
import unittest

# %%
df_battery = pd.read_csv('Battery_Dataset.csv')

# %%
import csv
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold 
import math

from notebook.services.config import ConfigManager
cm = ConfigManager().update('notebook', {'limit_output': 1000})
import statistics as stcs
import scipy.stats as stats

import sklearn as sk
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler,scale,MinMaxScaler
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from scipy.stats import uniform,expon
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

# %%
#One hot encoding (alphebetical order)
ohe = OneHotEncoder()
ACE = df_battery.loc[:,['anode','cathode','electrolyte']]
ACE = ohe.fit_transform(ACE)
ACE = pd.DataFrame(ACE.toarray())

ACE_col_name = ['A1','C1','C2','C3','E1','E2','E3']
for i in range(len(ACE.columns)):
    ACE = ACE.rename({ACE.columns[i]: ACE_col_name[i]}, axis=1) 
    
df_battery = pd.concat([ACE, df_battery],axis=1)

# %%
data = df_battery

np.random.seed(66)
def data_split (data, test_ratio):
    
    total_row = df_battery.shape[0]
    test_row = round(total_row *test_ratio)
    train_row = total_row - test_row
    
    indices =np.random.permutation(total_row)
    train_indx, test_idx =indices[:train_row], indices[train_row:]
    train,test = df_battery.iloc[train_indx,:], df_battery.iloc[test_idx,:]

    X_test = test[['A1','C1','C2','C3','E1','E2','E3','Cycle','temperature','discharge_crate']]
#    y_test = test[['Charge_Capacity (Ah)']]
#    y_test = test[['Discharge_Capacity (Ah)']]
#    y_test = test[['Charge_Energy (Wh)']]
#    y_test = test[['Discharge_Energy (Wh)']]
#    y_test = test[['Coulombic_Efficiency (%)']]
    y_test = test[['Energy_Efficiency (%)']]
    X_train = train[['A1','C1','C2','C3','E1','E2','E3','Cycle','temperature','discharge_crate']]
#    y_train = train[['Charge_Capacity (Ah)']]
#    y_train = train[['Discharge_Capacity (Ah)']]
#    y_train = train[['Charge_Energy (Wh)']]
#    y_train = train[['Discharge_Energy (Wh)']]
#    y_train = train[['Coulombic_Efficiency (%)']]
    y_train = train[['Energy_Efficiency (%)']]
    return train,test,X_train,y_train,X_test,y_test
    
train,test,X_train,y_train,X_test,y_test = data_split(data,0.2)

# %%
kf = KFold(n_splits=10,random_state =66,shuffle= True)

# %%
rand_para = {'n_estimators':[100, 200, 300, 400],
             'max_features':[1, 3, 5, 7],
             'max_depth': [6, 7, 8, 9]}
reg=RandomForestRegressor(random_state = 66,min_samples_leaf =1,min_samples_split=2)

n_iteration = 200
Scoring = ['explained_variance','neg_mean_squared_error',"r2"]
random_search = RandomizedSearchCV(reg,param_distributions=rand_para,cv =5,
error_score=0,random_state=66,return_train_score=True,n_jobs=-1,n_iter=n_iteration,verbose=10,refit=True)

random_search.fit(X_train,y_train)

#y_predict=random_search.predict(X_test)
#math.sqrt(stcs.mean((y_predict-y_test)**2))
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:292: UserWarning: The total space of parameters 64 is smaller than n_iter=200. Running 64 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...
# [CV 3/5; 12/64] END max_depth=6, max_features=5, n_estimators=400;, score=(train=0.943, test=0.902) total time=   0.7s
# [CV 1/5; 14/64] START max_depth=6, max_features=7, n_estimators=200.............
# [CV 1/5; 14/64] END max_depth=6, max_features=7, n_estimators=200;, score=(train=0.944, test=0.862) total time=   0.4s
# [CV 3/5; 15/64] START max_depth=6, max_features=7, n_estimators=300.............
# [CV 3/5; 15/64] END max_depth=6, max_features=7, n_estimators=300;, score=(train=0.944, test=0.900) total time=   0.5s
# [CV 1/5; 17/64] START max_depth=7, max_features=1, n_estimators=100.............
# [CV 1/5; 17/64] END max_depth=7, max_features=1, n_estimators=100;, score=(train=0.950, test=0.876) total time=   0.2s
# [CV 4/5; 17/64] START max_depth=7, max_features=1, n_estimators=100.............
# [CV 4/5; 17/64] END max_depth=7, max_features=1, n_estimators=100;, score=(train=0.945, test=0.906) total time=   0.2s
# [CV 2/5; 18/64] START max_depth=7, max_features=1, n_estimators=200.............
# [CV 2/5; 18/64] END max_depth=7, max_features=1, n_estimators=200;, score=(train=0.959, test=0.849) total time=   0.4s
# [CV 4/5; 19/64] START max_depth=7, max_features=1, n_estimators=300.............
# [CV 4/5; 19/64] END max_depth=7, max_features=1, n_estimators=300;, score=(train=0.947, test=0.910) total time=   0.6s
# [CV 2/5; 21/64] START max_depth=7, max_features=3, n_estimators=100.............
# [CV 2/5; 21/64] END max_depth=7, max_features=3, n_estimators=100;, score=(train=0.960, test=0.856) total time=   0.2s
# [CV 5/5; 21/64] START max_depth=7, max_features=3, n_estimators=100.............
# [CV 5/5; 21/64] END max_depth=7, max_features=3, n_estimators=100;, score=(train=0.956, test=0.875) total time=   0.2s
# [CV 1/5; 23/64] START max_depth=7, max_features=3, n_estimators=300.............
# [CV 1/5; 23/64] END max_depth=7, max_features=3, n_estimators=300;, score=(train=0.951, test=0.875) total time=   0.6s
# [CV 4/5; 24/64] START max_depth=7, max_features=3, n_estimators=400.............
# [CV 4/5; 24/64] END max_depth=7, max_features=3, n_estimators=400;, score=(train=0.949, test=0.916) total time=   0.9s
# [CV 2/5; 27/64] START max_depth=7, max_features=5, n_estimators=300.............
# [CV 2/5; 27/64] END max_depth=7, max_features=5, n_estimators=300;, score=(train=0.962, test=0.862) total time=   0.6s
# [CV 5/5; 28/64] START max_depth=7, max_features=5, n_estimators=400.............
# [CV 5/5; 28/64] END max_depth=7, max_features=5, n_estimators=400;, score=(train=0.960, test=0.868) total time=   0.9s
# [CV 3/5; 31/64] START max_depth=7, max_features=7, n_estimators=300.............
# [CV 3/5; 31/64] END max_depth=7, max_features=7, n_estimators=300;, score=(train=0.954, test=0.905) total time=   0.6s
# [CV 1/5; 33/64] START max_depth=8, max_features=1, n_estimators=100.............
# [CV 1/5; 33/64] END max_depth=8, max_features=1, n_estimators=100;, score=(train=0.956, test=0.866) total time=   0.3s
# [CV 4/5; 33/64] START max_depth=8, max_features=1, n_estimators=100.............
# [CV 4/5; 33/64] END max_depth=8, max_features=1, n_estimators=100;, score=(train=0.953, test=0.905) total time=   0.3s
# [CV 5/5; 34/64] START max_depth=8, max_features=1, n_estimators=200.............
# [CV 5/5; 34/64] END max_depth=8, max_features=1, n_estimators=200;, score=(train=0.960, test=0.866) total time=   0.6s
# [CV 3/5; 36/64] START max_depth=8, max_features=1, n_estimators=400.............
# [CV 3/5; 36/64] END max_depth=8, max_features=1, n_estimators=400;, score=(train=0.955, test=0.896) total time=   1.1s
# [CV 4/5; 38/64] START max_depth=8, max_features=3, n_estimators=200.............
# [CV 4/5; 38/64] END max_depth=8, max_features=3, n_estimators=200;, score=(train=0.955, test=0.914) total time=   0.5s
# [CV 1/5; 40/64] START max_depth=8, max_features=3, n_estimators=400.............
# [CV 1/5; 40/64] END max_depth=8, max_features=3, n_estimators=400;, score=(train=0.957, test=0.872) total time=   1.2s
# [CV 4/5; 41/64] START max_depth=8, max_features=5, n_estimators=100.............
# [CV 4/5; 41/64] END max_depth=8, max_features=5, n_estimators=100;, score=(train=0.956, test=0.915) total time=   0.3s
# [CV 5/5; 42/64] START max_depth=8, max_features=5, n_estimators=200.............
# [CV 5/5; 42/64] END max_depth=8, max_features=5, n_estimators=200;, score=(train=0.963, test=0.863) total time=   0.6s
# [CV 1/5; 44/64] START max_depth=8, max_features=5, n_estimators=400.............
# [CV 1/5; 44/64] END max_depth=8, max_features=5, n_estimators=400;, score=(train=0.958, test=0.869) total time=   1.1s
# [CV 5/5; 45/64] START max_depth=8, max_features=7, n_estimators=100.............
# [CV 5/5; 45/64] END max_depth=8, max_features=7, n_estimators=100;, score=(train=0.964, test=0.859) total time=   0.3s
# [CV 2/5; 47/64] START max_depth=8, max_features=7, n_estimators=300.............
# [CV 2/5; 47/64] END max_depth=8, max_features=7, n_estimators=300;, score=(train=0.969, test=0.864) total time=   0.8s
# [CV 5/5; 48/64] START max_depth=8, max_features=7, n_estimators=400.............
# [CV 5/5; 48/64] END max_depth=8, max_features=7, n_estimators=400;, score=(train=0.965, test=0.854) total time=   1.2s
# [CV 3/5; 51/64] START max_depth=9, max_features=1, n_estimators=300.............
# [CV 3/5; 51/64] END max_depth=9, max_features=1, n_estimators=300;, score=(train=0.959, test=0.891) total time=   0.9s
# [CV 1/5; 53/64] START max_depth=9, max_features=3, n_estimators=100.............
# [CV 1/5; 53/64] END max_depth=9, max_features=3, n_estimators=100;, score=(train=0.960, test=0.871) total time=   0.3s
# [CV 4/5; 53/64] START max_depth=9, max_features=3, n_estimators=100.............
# [CV 4/5; 53/64] END max_depth=9, max_features=3, n_estimators=100;, score=(train=0.956, test=0.913) total time=   0.3s
# [CV 5/5; 54/64] START max_depth=9, max_features=3, n_estimators=200.............
# [CV 5/5; 54/64] END max_depth=9, max_features=3, n_estimators=200;, score=(train=0.964, test=0.860) total time=   0.5s
# [CV 5/5; 55/64] START max_depth=9, max_features=3, n_estimators=300.............
# [CV 5/5; 55/64] END max_depth=9, max_features=3, n_estimators=300;, score=(train=0.964, test=0.861) total time=   1.0s
# [CV 3/5; 57/64] START max_depth=9, max_features=5, n_estimators=100.............
# [CV 3/5; 57/64] END max_depth=9, max_features=5, n_estimators=100;, score=(train=0.957, test=0.903) total time=   0.3s
# [CV 4/5; 58/64] START max_depth=9, max_features=5, n_estimators=200.............
# [CV 4/5; 58/64] END max_depth=9, max_features=5, n_estimators=200;, score=(train=0.958, test=0.915) total time=   0.6s
# [CV 1/5; 60/64] START max_depth=9, max_features=5, n_estimators=400.............
# [CV 1/5; 60/64] END max_depth=9, max_features=5, n_estimators=400;, score=(train=0.960, test=0.866) total time=   1.3s
# [CV 2/5; 62/64] START max_depth=9, max_features=7, n_estimators=200.............
# [CV 2/5; 62/64] END max_depth=9, max_features=7, n_estimators=200;, score=(train=0.971, test=0.862) total time=   0.6s
# [CV 5/5; 63/64] START max_depth=9, max_features=7, n_estimators=300.............
# [CV 4/5; 1/64] START max_depth=6, max_features=1, n_estimators=100..............
# [CV 4/5; 1/64] END max_depth=6, max_features=1, n_estimators=100;, score=(train=0.929, test=0.901) total time=   0.2s
# [CV 2/5; 3/64] START max_depth=6, max_features=1, n_estimators=300..............
# [CV 2/5; 3/64] END max_depth=6, max_features=1, n_estimators=300;, score=(train=0.944, test=0.843) total time=   0.5s
# [CV 1/5; 5/64] START max_depth=6, max_features=3, n_estimators=100..............
# [CV 1/5; 5/64] END max_depth=6, max_features=3, n_estimators=100;, score=(train=0.939, test=0.874) total time=   0.2s
# [CV 4/5; 5/64] START max_depth=6, max_features=3, n_estimators=100..............
# [CV 4/5; 5/64] END max_depth=6, max_features=3, n_estimators=100;, score=(train=0.937, test=0.915) total time=   0.2s
# [CV 2/5; 6/64] START max_depth=6, max_features=3, n_estimators=200..............
# [CV 2/5; 6/64] END max_depth=6, max_features=3, n_estimators=200;, score=(train=0.949, test=0.853) total time=   0.4s
# [CV 5/5; 7/64] START max_depth=6, max_features=3, n_estimators=300..............
# [CV 5/5; 7/64] END max_depth=6, max_features=3, n_estimators=300;, score=(train=0.946, test=0.886) total time=   0.6s
# [CV 3/5; 9/64] START max_depth=6, max_features=5, n_estimators=100..............
# [CV 3/5; 9/64] END max_depth=6, max_features=5, n_estimators=100;, score=(train=0.943, test=0.906) total time=   0.2s
# [CV 3/5; 10/64] START max_depth=6, max_features=5, n_estimators=200.............
# [CV 3/5; 10/64] END max_depth=6, max_features=5, n_estimators=200;, score=(train=0.944, test=0.904) total time=   0.4s
# [CV 1/5; 12/64] START max_depth=6, max_features=5, n_estimators=400.............
# [CV 1/5; 12/64] END max_depth=6, max_features=5, n_estimators=400;, score=(train=0.943, test=0.869) total time=   0.9s
# [CV 3/5; 14/64] START max_depth=6, max_features=7, n_estimators=200.............
# [CV 3/5; 14/64] END max_depth=6, max_features=7, n_estimators=200;, score=(train=0.944, test=0.900) total time=   0.5s
# [CV 2/5; 16/64] START max_depth=6, max_features=7, n_estimators=400.............
# [CV 2/5; 16/64] END max_depth=6, max_features=7, n_estimators=400;, score=(train=0.954, test=0.859) total time=   0.7s
# [CV 4/5; 18/64] START max_depth=7, max_features=1, n_estimators=200.............
# [CV 4/5; 18/64] END max_depth=7, max_features=1, n_estimators=200;, score=(train=0.947, test=0.909) total time=   0.4s
# [CV 2/5; 20/64] START max_depth=7, max_features=1, n_estimators=400.............
# [CV 2/5; 20/64] END max_depth=7, max_features=1, n_estimators=400;, score=(train=0.960, test=0.850) total time=   0.8s
# [CV 3/5; 22/64] START max_depth=7, max_features=3, n_estimators=200.............
# [CV 3/5; 22/64] END max_depth=7, max_features=3, n_estimators=200;, score=(train=0.949, test=0.899) total time=   0.4s
# [CV 1/5; 24/64] START max_depth=7, max_features=3, n_estimators=400.............
# [CV 1/5; 24/64] END max_depth=7, max_features=3, n_estimators=400;, score=(train=0.951, test=0.875) total time=   0.9s
# [CV 3/5; 26/64] START max_depth=7, max_features=5, n_estimators=200.............
# [CV 3/5; 26/64] END max_depth=7, max_features=5, n_estimators=200;, score=(train=0.953, test=0.902) total time=   0.5s
# [CV 2/5; 28/64] START max_depth=7, max_features=5, n_estimators=400.............
# [CV 2/5; 28/64] END max_depth=7, max_features=5, n_estimators=400;, score=(train=0.962, test=0.862) total time=   0.9s
# [CV 3/5; 30/64] START max_depth=7, max_features=7, n_estimators=200.............
# [CV 3/5; 30/64] END max_depth=7, max_features=7, n_estimators=200;, score=(train=0.953, test=0.908) total time=   0.4s
# [CV 4/5; 31/64] START max_depth=7, max_features=7, n_estimators=300.............
# [CV 4/5; 31/64] END max_depth=7, max_features=7, n_estimators=300;, score=(train=0.953, test=0.917) total time=   0.7s
# [CV 2/5; 33/64] START max_depth=8, max_features=1, n_estimators=100.............
# [CV 2/5; 33/64] END max_depth=8, max_features=1, n_estimators=100;, score=(train=0.965, test=0.852) total time=   0.3s
# [CV 2/5; 34/64] START max_depth=8, max_features=1, n_estimators=200.............
# [CV 2/5; 34/64] END max_depth=8, max_features=1, n_estimators=200;, score=(train=0.966, test=0.855) total time=   0.6s
# [CV 4/5; 35/64] START max_depth=8, max_features=1, n_estimators=300.............
# [CV 4/5; 35/64] END max_depth=8, max_features=1, n_estimators=300;, score=(train=0.954, test=0.906) total time=   0.9s
# [CV 1/5; 37/64] START max_depth=8, max_features=3, n_estimators=100.............
# [CV 1/5; 37/64] END max_depth=8, max_features=3, n_estimators=100;, score=(train=0.957, test=0.881) total time=   0.3s
# [CV 2/5; 38/64] START max_depth=8, max_features=3, n_estimators=200.............
# [CV 2/5; 38/64] END max_depth=8, max_features=3, n_estimators=200;, score=(train=0.967, test=0.859) total time=   0.5s
# [CV 5/5; 39/64] START max_depth=8, max_features=3, n_estimators=300.............
# [CV 5/5; 39/64] END max_depth=8, max_features=3, n_estimators=300;, score=(train=0.962, test=0.867) total time=   0.9s
# [CV 3/5; 41/64] START max_depth=8, max_features=5, n_estimators=100.............
# [CV 3/5; 41/64] END max_depth=8, max_features=5, n_estimators=100;, score=(train=0.956, test=0.905) total time=   0.4s
# [CV 3/5; 42/64] START max_depth=8, max_features=5, n_estimators=200.............
# [CV 3/5; 42/64] END max_depth=8, max_features=5, n_estimators=200;, score=(train=0.957, test=0.901) total time=   0.6s
# [CV 5/5; 43/64] START max_depth=8, max_features=5, n_estimators=300.............
# [CV 5/5; 43/64] END max_depth=8, max_features=5, n_estimators=300;, score=(train=0.964, test=0.862) total time=   0.9s
# [CV 2/5; 45/64] START max_depth=8, max_features=7, n_estimators=100.............
# [CV 2/5; 45/64] END max_depth=8, max_features=7, n_estimators=100;, score=(train=0.968, test=0.861) total time=   0.3s
# [CV 1/5; 46/64] START max_depth=8, max_features=7, n_estimators=200.............
# [CV 1/5; 46/64] END max_depth=8, max_features=7, n_estimators=200;, score=(train=0.958, test=0.865) total time=   0.6s
# [CV 4/5; 47/64] START max_depth=8, max_features=7, n_estimators=300.............
# [CV 4/5; 47/64] END max_depth=8, max_features=7, n_estimators=300;, score=(train=0.957, test=0.916) total time=   0.9s
# [CV 2/5; 49/64] START max_depth=9, max_features=1, n_estimators=100.............
# [CV 2/5; 49/64] END max_depth=9, max_features=1, n_estimators=100;, score=(train=0.968, test=0.855) total time=   0.3s
# [CV 1/5; 50/64] START max_depth=9, max_features=1, n_estimators=200.............
# [CV 1/5; 50/64] END max_depth=9, max_features=1, n_estimators=200;, score=(train=0.960, test=0.867) total time=   0.5s
# [CV 4/5; 51/64] START max_depth=9, max_features=1, n_estimators=300.............
# [CV 4/5; 51/64] END max_depth=9, max_features=1, n_estimators=300;, score=(train=0.957, test=0.907) total time=   1.0s
# [CV 2/5; 53/64] START max_depth=9, max_features=3, n_estimators=100.............
# [CV 2/5; 53/64] END max_depth=9, max_features=3, n_estimators=100;, score=(train=0.969, test=0.858) total time=   0.3s
# [CV 2/5; 54/64] START max_depth=9, max_features=3, n_estimators=200.............
# [CV 2/5; 54/64] END max_depth=9, max_features=3, n_estimators=200;, score=(train=0.970, test=0.858) total time=   0.6s
# [CV 1/5; 56/64] START max_depth=9, max_features=3, n_estimators=400.............
# [CV 1/5; 56/64] END max_depth=9, max_features=3, n_estimators=400;, score=(train=0.960, test=0.868) total time=   1.3s
# [CV 5/5; 57/64] START max_depth=9, max_features=5, n_estimators=100.............
# [CV 5/5; 57/64] END max_depth=9, max_features=5, n_estimators=100;, score=(train=0.964, test=0.857) total time=   0.3s
# [CV 1/5; 59/64] START max_depth=9, max_features=5, n_estimators=300.............
# [CV 1/5; 59/64] END max_depth=9, max_features=5, n_estimators=300;, score=(train=0.960, test=0.865) total time=   1.1s
# [CV 5/5; 60/64] START max_depth=9, max_features=5, n_estimators=400.............
# [CV 5/5; 60/64] END max_depth=9, max_features=5, n_estimators=400;, score=(train=0.965, test=0.853) total time=   1.1s
# [CV 4/5; 63/64] START max_depth=9, max_features=7, n_estimators=300.............
# [CV 4/5; 63/64] END max_depth=9, max_features=7, n_estimators=300;, score=(train=0.959, test=0.916) total time=   0.8s
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py:926: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# RandomizedSearchCV(cv=5, error_score=0,
#                    estimator=RandomForestRegressor(random_state=66), n_iter=200,
#                    n_jobs=-1,
#                    param_distributions={'max_depth': [6, 7, 8, 9],
#                                         'max_features': [1, 3, 5, 7],
#                                         'n_estimators': [100, 200, 300, 400]},
#                    random_state=66, return_train_score=True, verbose=10)

# %%
RF_model_Capacity =RandomForestRegressor(n_estimators=666,min_samples_split=5,
             max_depth=7,min_samples_leaf=1,random_state = 66)

train_results =[]
train_results_name =['Experimental','Predicted','RMSE']


for train_index, test_index in kf.split(X_train):
    #print("Train:", train_index, "Validation:", test_index)
    X_training, X_validate = X_train.iloc[train_index], X_train.iloc[test_index]
    y_training, y_validate = y_train.iloc[train_index], y_train.iloc[test_index]
    
    np.random.seed(66)
    RF_model_Capacity.fit(X_training,y_training)
    y_train_predicted = RF_model_Capacity.predict(X_validate)
#     number_validate =X_validate.shape[0]
    mse = mean_squared_error(y_train_predicted, y_validate)
    RMSE = np.sqrt(mse)
#     Y_train_predicted = y_train_predicted.reshape(24,1)
#     print(y_train_predicted.shape)
#     squared_deviations = (y_train_predicted.reshape(24,1) - y_validate)**2
#     RMSE=math.sqrt(squared_deviations.sum()/number_validate)
    train_results.append([y_validate,y_train_predicted,RMSE])
# Out:
# /tmp/ipykernel_1973/445779285.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model_Capacity.fit(X_training,y_training)
# /tmp/ipykernel_1973/445779285.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model_Capacity.fit(X_training,y_training)
# /tmp/ipykernel_1973/445779285.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model_Capacity.fit(X_training,y_training)
# /tmp/ipykernel_1973/445779285.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model_Capacity.fit(X_training,y_training)
# /tmp/ipykernel_1973/445779285.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model_Capacity.fit(X_training,y_training)
# /tmp/ipykernel_1973/445779285.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model_Capacity.fit(X_training,y_training)
# /tmp/ipykernel_1973/445779285.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model_Capacity.fit(X_training,y_training)
# /tmp/ipykernel_1973/445779285.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model_Capacity.fit(X_training,y_training)
# /tmp/ipykernel_1973/445779285.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model_Capacity.fit(X_training,y_training)
# /tmp/ipykernel_1973/445779285.py:14: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model_Capacity.fit(X_training,y_training)

# %%
Train_results = pd.DataFrame (train_results,columns=train_results_name)

predict_results = pd.DataFrame (Train_results.iloc[:,1])

np.average(Train_results['RMSE'])
# Out:
# 1.7504181557146967

# %%
np.random.seed(66)
RF_model_Capacity.fit(X_train,y_train)
y_predict = RF_model_Capacity.predict(X_test)
#math.sqrt(stcs.mean((y_predict.reshape(80,1)-y_test)**2))

mse = mean_squared_error(y_train_predicted, y_validate)
RMSE = np.sqrt(mse)
RMSE
# number_test =X_test.shape[0]
# squared_deviations=(y_predict.reshape(80,1)-y_test)**2
# math.sqrt(squared_deviations.sum()/number_test)
# Out:
# /tmp/ipykernel_1973/728272610.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model_Capacity.fit(X_train,y_train)
# 1.340724863673869

# %%
"""
total = sum((y_test-stcs.mean(y_test))**2)
unexplained = sum((y_test-y_predict)**2)

R_square_test = 1-(unexplained/total)
"""
# Out:
# '\ntotal = sum((y_test-stcs.mean(y_test))**2)\nunexplained = sum((y_test-y_predict)**2)\n\nR_square_test = 1-(unexplained/total)\n'

# %%
"""
R_square_test
"""
# Out:
# '\nR_square_test\n'
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [CV 5/5; 63/64] END max_depth=9, max_features=7, n_estimators=300;, score=(train=0.966, test=0.856) total time=   0.8s
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [CV 1/5; 2/64] START max_depth=6, max_features=1, n_estimators=200..............
# [CV 1/5; 2/64] END max_depth=6, max_features=1, n_estimators=200;, score=(train=0.935, test=0.869) total time=   0.3s
# [CV 4/5; 3/64] START max_depth=6, max_features=1, n_estimators=300..............
# [CV 4/5; 3/64] END max_depth=6, max_features=1, n_estimators=300;, score=(train=0.931, test=0.905) total time=   0.5s
# [CV 2/5; 5/64] START max_depth=6, max_features=3, n_estimators=100..............
# [CV 2/5; 5/64] END max_depth=6, max_features=3, n_estimators=100;, score=(train=0.949, test=0.850) total time=   0.2s
# [CV 5/5; 5/64] START max_depth=6, max_features=3, n_estimators=100..............
# [CV 5/5; 5/64] END max_depth=6, max_features=3, n_estimators=100;, score=(train=0.942, test=0.890) total time=   0.2s
# [CV 5/5; 6/64] START max_depth=6, max_features=3, n_estimators=200..............
# [CV 5/5; 6/64] END max_depth=6, max_features=3, n_estimators=200;, score=(train=0.943, test=0.886) total time=   0.4s
# [CV 3/5; 8/64] START max_depth=6, max_features=3, n_estimators=400..............
# [CV 3/5; 8/64] END max_depth=6, max_features=3, n_estimators=400;, score=(train=0.940, test=0.902) total time=   0.7s
# [CV 2/5; 10/64] START max_depth=6, max_features=5, n_estimators=200.............
# [CV 2/5; 10/64] END max_depth=6, max_features=5, n_estimators=200;, score=(train=0.951, test=0.856) total time=   0.4s
# [CV 4/5; 11/64] START max_depth=6, max_features=5, n_estimators=300.............
# [CV 4/5; 11/64] END max_depth=6, max_features=5, n_estimators=300;, score=(train=0.943, test=0.922) total time=   0.5s
# [CV 2/5; 13/64] START max_depth=6, max_features=7, n_estimators=100.............
# [CV 2/5; 13/64] END max_depth=6, max_features=7, n_estimators=100;, score=(train=0.953, test=0.857) total time=   0.2s
# [CV 5/5; 13/64] START max_depth=6, max_features=7, n_estimators=100.............
# [CV 5/5; 13/64] END max_depth=6, max_features=7, n_estimators=100;, score=(train=0.955, test=0.875) total time=   0.2s
# [CV 1/5; 15/64] START max_depth=6, max_features=7, n_estimators=300.............
# [CV 1/5; 15/64] END max_depth=6, max_features=7, n_estimators=300;, score=(train=0.943, test=0.861) total time=   0.6s
# [CV 4/5; 16/64] START max_depth=6, max_features=7, n_estimators=400.............
# [CV 4/5; 16/64] END max_depth=6, max_features=7, n_estimators=400;, score=(train=0.944, test=0.921) total time=   0.7s
# [CV 2/5; 19/64] START max_depth=7, max_features=1, n_estimators=300.............
# [CV 2/5; 19/64] END max_depth=7, max_features=1, n_estimators=300;, score=(train=0.959, test=0.850) total time=   0.6s
# [CV 5/5; 20/64] START max_depth=7, max_features=1, n_estimators=400.............
# [CV 5/5; 20/64] END max_depth=7, max_features=1, n_estimators=400;, score=(train=0.954, test=0.867) total time=   0.8s
# [CV 3/5; 23/64] START max_depth=7, max_features=3, n_estimators=300.............
# [CV 3/5; 23/64] END max_depth=7, max_features=3, n_estimators=300;, score=(train=0.950, test=0.900) total time=   0.6s
# [CV 1/5; 25/64] START max_depth=7, max_features=5, n_estimators=100.............
# [CV 1/5; 25/64] END max_depth=7, max_features=5, n_estimators=100;, score=(train=0.953, test=0.867) total time=   0.2s
# [CV 4/5; 25/64] START max_depth=7, max_features=5, n_estimators=100.............
# [CV 4/5; 25/64] END max_depth=7, max_features=5, n_estimators=100;, score=(train=0.951, test=0.921) total time=   0.2s
# [CV 4/5; 26/64] START max_depth=7, max_features=5, n_estimators=200.............
# [CV 4/5; 26/64] END max_depth=7, max_features=5, n_estimators=200;, score=(train=0.952, test=0.920) total time=   0.4s
# [CV 1/5; 28/64] START max_depth=7, max_features=5, n_estimators=400.............
# [CV 1/5; 28/64] END max_depth=7, max_features=5, n_estimators=400;, score=(train=0.952, test=0.869) total time=   0.9s
# [CV 5/5; 29/64] START max_depth=7, max_features=7, n_estimators=100.............
# [CV 5/5; 29/64] END max_depth=7, max_features=7, n_estimators=100;, score=(train=0.962, test=0.870) total time=   0.2s
# [CV 1/5; 31/64] START max_depth=7, max_features=7, n_estimators=300.............
# [CV 1/5; 31/64] END max_depth=7, max_features=7, n_estimators=300;, score=(train=0.953, test=0.867) total time=   0.6s
# [CV 4/5; 32/64] START max_depth=7, max_features=7, n_estimators=400.............
# [CV 4/5; 32/64] END max_depth=7, max_features=7, n_estimators=400;, score=(train=0.953, test=0.917) total time=   1.0s
# [CV 2/5; 35/64] START max_depth=8, max_features=1, n_estimators=300.............
# [CV 2/5; 35/64] END max_depth=8, max_features=1, n_estimators=300;, score=(train=0.966, test=0.855) total time=   0.9s
# [CV 5/5; 36/64] START max_depth=8, max_features=1, n_estimators=400.............
# [CV 5/5; 36/64] END max_depth=8, max_features=1, n_estimators=400;, score=(train=0.960, test=0.860) total time=   1.1s
# [CV 3/5; 39/64] START max_depth=8, max_features=3, n_estimators=300.............
# [CV 3/5; 39/64] END max_depth=8, max_features=3, n_estimators=300;, score=(train=0.956, test=0.895) total time=   0.8s
# [CV 1/5; 41/64] START max_depth=8, max_features=5, n_estimators=100.............
# [CV 1/5; 41/64] END max_depth=8, max_features=5, n_estimators=100;, score=(train=0.957, test=0.869) total time=   0.4s
# [CV 5/5; 41/64] START max_depth=8, max_features=5, n_estimators=100.............
# [CV 5/5; 41/64] END max_depth=8, max_features=5, n_estimators=100;, score=(train=0.963, test=0.866) total time=   0.3s
# [CV 1/5; 43/64] START max_depth=8, max_features=5, n_estimators=300.............
# [CV 1/5; 43/64] END max_depth=8, max_features=5, n_estimators=300;, score=(train=0.958, test=0.870) total time=   0.8s
# [CV 4/5; 44/64] START max_depth=8, max_features=5, n_estimators=400.............
# [CV 4/5; 44/64] END max_depth=8, max_features=5, n_estimators=400;, score=(train=0.957, test=0.914) total time=   1.1s
# [CV 1/5; 47/64] START max_depth=8, max_features=7, n_estimators=300.............
# [CV 1/5; 47/64] END max_depth=8, max_features=7, n_estimators=300;, score=(train=0.958, test=0.864) total time=   0.8s
# [CV 4/5; 48/64] START max_depth=8, max_features=7, n_estimators=400.............
# [CV 4/5; 48/64] END max_depth=8, max_features=7, n_estimators=400;, score=(train=0.957, test=0.915) total time=   1.1s
# [CV 2/5; 51/64] START max_depth=9, max_features=1, n_estimators=300.............
# [CV 2/5; 51/64] END max_depth=9, max_features=1, n_estimators=300;, score=(train=0.970, test=0.857) total time=   0.9s
# [CV 5/5; 52/64] START max_depth=9, max_features=1, n_estimators=400.............
# [CV 5/5; 52/64] END max_depth=9, max_features=1, n_estimators=400;, score=(train=0.963, test=0.857) total time=   1.1s
# [CV 3/5; 55/64] START max_depth=9, max_features=3, n_estimators=300.............
# [CV 3/5; 55/64] END max_depth=9, max_features=3, n_estimators=300;, score=(train=0.959, test=0.894) total time=   1.0s
# [CV 1/5; 57/64] START max_depth=9, max_features=5, n_estimators=100.............
# [CV 1/5; 57/64] END max_depth=9, max_features=5, n_estimators=100;, score=(train=0.960, test=0.857) total time=   0.3s
# [CV 4/5; 57/64] START max_depth=9, max_features=5, n_estimators=100.............
# [CV 4/5; 57/64] END max_depth=9, max_features=5, n_estimators=100;, score=(train=0.957, test=0.914) total time=   0.3s
# [CV 5/5; 58/64] START max_depth=9, max_features=5, n_estimators=200.............
# [CV 5/5; 58/64] END max_depth=9, max_features=5, n_estimators=200;, score=(train=0.965, test=0.854) total time=   0.6s
# [CV 3/5; 60/64] START max_depth=9, max_features=5, n_estimators=400.............
# [CV 3/5; 60/64] END max_depth=9, max_features=5, n_estimators=400;, score=(train=0.959, test=0.898) total time=   1.2s
# [CV 1/5; 62/64] START max_depth=9, max_features=7, n_estimators=200.............
# [CV 1/5; 62/64] END max_depth=9, max_features=7, n_estimators=200;, score=(train=0.961, test=0.862) total time=   0.5s
# [CV 3/5; 63/64] START max_depth=9, max_features=7, n_estimators=300.............
# [CV 3/5; 63/64] END max_depth=9, max_features=7, n_estimators=300;, score=(train=0.959, test=0.899) total time=   0.8s
# [CV 1/5; 1/64] START max_depth=6, max_features=1, n_estimators=100..............
# [CV 1/5; 1/64] END max_depth=6, max_features=1, n_estimators=100;, score=(train=0.935, test=0.864) total time=   0.2s
# [CV 1/5; 3/64] START max_depth=6, max_features=1, n_estimators=300..............
# [CV 1/5; 3/64] END max_depth=6, max_features=1, n_estimators=300;, score=(train=0.936, test=0.872) total time=   0.5s
# [CV 5/5; 4/64] START max_depth=6, max_features=1, n_estimators=400..............
# [CV 5/5; 4/64] END max_depth=6, max_features=1, n_estimators=400;, score=(train=0.940, test=0.878) total time=   0.8s
# [CV 4/5; 7/64] START max_depth=6, max_features=3, n_estimators=300..............
# [CV 4/5; 7/64] END max_depth=6, max_features=3, n_estimators=300;, score=(train=0.938, test=0.918) total time=   0.6s
# [CV 2/5; 9/64] START max_depth=6, max_features=5, n_estimators=100..............
# [CV 2/5; 9/64] END max_depth=6, max_features=5, n_estimators=100;, score=(train=0.950, test=0.856) total time=   0.2s
# [CV 1/5; 10/64] START max_depth=6, max_features=5, n_estimators=200.............
# [CV 1/5; 10/64] END max_depth=6, max_features=5, n_estimators=200;, score=(train=0.944, test=0.876) total time=   0.4s
# [CV 5/5; 11/64] START max_depth=6, max_features=5, n_estimators=300.............
# [CV 5/5; 11/64] END max_depth=6, max_features=5, n_estimators=300;, score=(train=0.953, test=0.878) total time=   0.5s
# [CV 3/5; 13/64] START max_depth=6, max_features=7, n_estimators=100.............
# [CV 3/5; 13/64] END max_depth=6, max_features=7, n_estimators=100;, score=(train=0.943, test=0.902) total time=   0.3s
# [CV 2/5; 14/64] START max_depth=6, max_features=7, n_estimators=200.............
# [CV 2/5; 14/64] END max_depth=6, max_features=7, n_estimators=200;, score=(train=0.954, test=0.859) total time=   0.5s
# [CV 5/5; 15/64] START max_depth=6, max_features=7, n_estimators=300.............
# [CV 5/5; 15/64] END max_depth=6, max_features=7, n_estimators=300;, score=(train=0.955, test=0.875) total time=   0.5s
# [CV 3/5; 17/64] START max_depth=7, max_features=1, n_estimators=100.............
# [CV 3/5; 17/64] END max_depth=7, max_features=1, n_estimators=100;, score=(train=0.946, test=0.892) total time=   0.2s
# [CV 3/5; 18/64] START max_depth=7, max_features=1, n_estimators=200.............
# [CV 3/5; 18/64] END max_depth=7, max_features=1, n_estimators=200;, score=(train=0.948, test=0.897) total time=   0.4s
# [CV 1/5; 20/64] START max_depth=7, max_features=1, n_estimators=400.............
# [CV 1/5; 20/64] END max_depth=7, max_features=1, n_estimators=400;, score=(train=0.950, test=0.877) total time=   0.8s
# [CV 1/5; 22/64] START max_depth=7, max_features=3, n_estimators=200.............
# [CV 1/5; 22/64] END max_depth=7, max_features=3, n_estimators=200;, score=(train=0.950, test=0.875) total time=   0.4s
# [CV 5/5; 23/64] START max_depth=7, max_features=3, n_estimators=300.............
# [CV 5/5; 23/64] END max_depth=7, max_features=3, n_estimators=300;, score=(train=0.957, test=0.872) total time=   0.7s
# [CV 3/5; 25/64] START max_depth=7, max_features=5, n_estimators=100.............
# [CV 3/5; 25/64] END max_depth=7, max_features=5, n_estimators=100;, score=(train=0.952, test=0.909) total time=   0.2s
# [CV 2/5; 26/64] START max_depth=7, max_features=5, n_estimators=200.............
# [CV 2/5; 26/64] END max_depth=7, max_features=5, n_estimators=200;, score=(train=0.962, test=0.862) total time=   0.5s
# [CV 5/5; 27/64] START max_depth=7, max_features=5, n_estimators=300.............
# [CV 5/5; 27/64] END max_depth=7, max_features=5, n_estimators=300;, score=(train=0.960, test=0.868) total time=   0.7s
# [CV 3/5; 29/64] START max_depth=7, max_features=7, n_estimators=100.............
# [CV 3/5; 29/64] END max_depth=7, max_features=7, n_estimators=100;, score=(train=0.952, test=0.913) total time=   0.3s
# [CV 4/5; 30/64] START max_depth=7, max_features=7, n_estimators=200.............
# [CV 4/5; 30/64] END max_depth=7, max_features=7, n_estimators=200;, score=(train=0.953, test=0.918) total time=   0.5s
# [CV 2/5; 32/64] START max_depth=7, max_features=7, n_estimators=400.............
# [CV 2/5; 32/64] END max_depth=7, max_features=7, n_estimators=400;, score=(train=0.964, test=0.864) total time=   0.9s
# [CV 5/5; 33/64] START max_depth=8, max_features=1, n_estimators=100.............
# [CV 5/5; 33/64] END max_depth=8, max_features=1, n_estimators=100;, score=(train=0.959, test=0.864) total time=   0.3s
# [CV 1/5; 35/64] START max_depth=8, max_features=1, n_estimators=300.............
# [CV 1/5; 35/64] END max_depth=8, max_features=1, n_estimators=300;, score=(train=0.957, test=0.877) total time=   0.9s
# [CV 4/5; 36/64] START max_depth=8, max_features=1, n_estimators=400.............
# [CV 4/5; 36/64] END max_depth=8, max_features=1, n_estimators=400;, score=(train=0.955, test=0.907) total time=   1.1s
# [CV 2/5; 39/64] START max_depth=8, max_features=3, n_estimators=300.............
# [CV 2/5; 39/64] END max_depth=8, max_features=3, n_estimators=300;, score=(train=0.967, test=0.860) total time=   0.8s
# [CV 5/5; 40/64] START max_depth=8, max_features=3, n_estimators=400.............
# [CV 5/5; 40/64] END max_depth=8, max_features=3, n_estimators=400;, score=(train=0.962, test=0.866) total time=   1.4s
# [CV 3/5; 44/64] START max_depth=8, max_features=5, n_estimators=400.............
# [CV 3/5; 44/64] END max_depth=8, max_features=5, n_estimators=400;, score=(train=0.957, test=0.900) total time=   1.2s
# [CV 4/5; 46/64] START max_depth=8, max_features=7, n_estimators=200.............
# [CV 4/5; 46/64] END max_depth=8, max_features=7, n_estimators=200;, score=(train=0.957, test=0.916) total time=   0.7s
# [CV 3/5; 48/64] START max_depth=8, max_features=7, n_estimators=400.............
# [CV 3/5; 48/64] END max_depth=8, max_features=7, n_estimators=400;, score=(train=0.958, test=0.904) total time=   1.2s
# [CV 3/5; 50/64] START max_depth=9, max_features=1, n_estimators=200.............
# [CV 3/5; 50/64] END max_depth=9, max_features=1, n_estimators=200;, score=(train=0.958, test=0.894) total time=   0.5s
# [CV 1/5; 52/64] START max_depth=9, max_features=1, n_estimators=400.............
# [CV 1/5; 52/64] END max_depth=9, max_features=1, n_estimators=400;, score=(train=0.960, test=0.867) total time=   1.2s
# [CV 1/5; 54/64] START max_depth=9, max_features=3, n_estimators=200.............
# [CV 1/5; 54/64] END max_depth=9, max_features=3, n_estimators=200;, score=(train=0.960, test=0.868) total time=   0.6s
# [CV 4/5; 55/64] START max_depth=9, max_features=3, n_estimators=300.............
# [CV 4/5; 55/64] END max_depth=9, max_features=3, n_estimators=300;, score=(train=0.958, test=0.914) total time=   1.0s
# [CV 2/5; 57/64] START max_depth=9, max_features=5, n_estimators=100.............
# [CV 2/5; 57/64] END max_depth=9, max_features=5, n_estimators=100;, score=(train=0.969, test=0.857) total time=   0.3s
# [CV 1/5; 58/64] START max_depth=9, max_features=5, n_estimators=200.............
# [CV 1/5; 58/64] END max_depth=9, max_features=5, n_estimators=200;, score=(train=0.960, test=0.867) total time=   0.6s
# [CV 5/5; 59/64] START max_depth=9, max_features=5, n_estimators=300.............
# [CV 5/5; 59/64] END max_depth=9, max_features=5, n_estimators=300;, score=(train=0.965, test=0.852) total time=   1.0s
# [CV 3/5; 61/64] START max_depth=9, max_features=7, n_estimators=100.............
# [CV 3/5; 61/64] END max_depth=9, max_features=7, n_estimators=100;, score=(train=0.958, test=0.907) total time=   0.3s
# [CV 4/5; 62/64] START max_depth=9, max_features=7, n_estimators=200.............
# [CV 4/5; 62/64] END max_depth=9, max_features=7, n_estimators=200;, score=(train=0.959, test=0.915) total time=   0.6s
# [CV 1/5; 64/64] START max_depth=9, max_features=7, n_estimators=400.............
# [CV 1/5; 64/64] END max_depth=9, max_features=7, n_estimators=400;, score=(train=0.961, test=0.863) total time=   1.0s
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [CV 4/5; 61/64] END max_depth=9, max_features=7, n_estimators=100;, score=(train=0.958, test=0.915) total time=   0.3s
# [CV 5/5; 62/64] START max_depth=9, max_features=7, n_estimators=200.............
# [CV 5/5; 62/64] END max_depth=9, max_features=7, n_estimators=200;, score=(train=0.966, test=0.856) total time=   0.5s
# [CV 3/5; 64/64] START max_depth=9, max_features=7, n_estimators=400.............
# [CV 3/5; 64/64] END max_depth=9, max_features=7, n_estimators=400;, score=(train=0.959, test=0.900) total time=   1.0s
# [CV 3/5; 62/64] END max_depth=9, max_features=7, n_estimators=200;, score=(train=0.959, test=0.902) total time=   0.6s
# [CV 2/5; 64/64] START max_depth=9, max_features=7, n_estimators=400.............
# [CV 2/5; 64/64] END max_depth=9, max_features=7, n_estimators=400;, score=(train=0.971, test=0.862) total time=   1.0s
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/kli625/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [CV 2/5; 1/64] START max_depth=6, max_features=1, n_estimators=100..............
# [CV 2/5; 1/64] END max_depth=6, max_features=1, n_estimators=100;, score=(train=0.938, test=0.838) total time=   0.2s
# [CV 5/5; 2/64] START max_depth=6, max_features=1, n_estimators=200..............
# [CV 5/5; 2/64] END max_depth=6, max_features=1, n_estimators=200;, score=(train=0.939, test=0.881) total time=   0.4s
# [CV 3/5; 4/64] START max_depth=6, max_features=1, n_estimators=400..............
# [CV 3/5; 4/64] END max_depth=6, max_features=1, n_estimators=400;, score=(train=0.933, test=0.902) total time=   0.7s
# [CV 1/5; 7/64] START max_depth=6, max_features=3, n_estimators=300..............
# [CV 1/5; 7/64] END max_depth=6, max_features=3, n_estimators=300;, score=(train=0.940, test=0.872) total time=   0.7s
# [CV 4/5; 8/64] START max_depth=6, max_features=3, n_estimators=400..............
# [CV 4/5; 8/64] END max_depth=6, max_features=3, n_estimators=400;, score=(train=0.939, test=0.917) total time=   0.7s
# [CV 2/5; 11/64] START max_depth=6, max_features=5, n_estimators=300.............
# [CV 2/5; 11/64] END max_depth=6, max_features=5, n_estimators=300;, score=(train=0.951, test=0.856) total time=   0.6s
# [CV 5/5; 12/64] START max_depth=6, max_features=5, n_estimators=400.............
# [CV 5/5; 12/64] END max_depth=6, max_features=5, n_estimators=400;, score=(train=0.953, test=0.878) total time=   1.0s
# [CV 3/5; 16/64] START max_depth=6, max_features=7, n_estimators=400.............
# [CV 3/5; 16/64] END max_depth=6, max_features=7, n_estimators=400;, score=(train=0.944, test=0.900) total time=   0.7s
# [CV 5/5; 18/64] START max_depth=7, max_features=1, n_estimators=200.............
# [CV 5/5; 18/64] END max_depth=7, max_features=1, n_estimators=200;, score=(train=0.954, test=0.870) total time=   0.4s
# [CV 3/5; 20/64] START max_depth=7, max_features=1, n_estimators=400.............
# [CV 3/5; 20/64] END max_depth=7, max_features=1, n_estimators=400;, score=(train=0.949, test=0.899) total time=   0.8s
# [CV 4/5; 22/64] START max_depth=7, max_features=3, n_estimators=200.............
# [CV 4/5; 22/64] END max_depth=7, max_features=3, n_estimators=200;, score=(train=0.948, test=0.917) total time=   0.4s
# [CV 2/5; 24/64] START max_depth=7, max_features=3, n_estimators=400.............
# [CV 2/5; 24/64] END max_depth=7, max_features=3, n_estimators=400;, score=(train=0.961, test=0.859) total time=   0.9s
# [CV 5/5; 26/64] START max_depth=7, max_features=5, n_estimators=200.............
# [CV 5/5; 26/64] END max_depth=7, max_features=5, n_estimators=200;, score=(train=0.960, test=0.869) total time=   0.5s
# [CV 3/5; 28/64] START max_depth=7, max_features=5, n_estimators=400.............
# [CV 3/5; 28/64] END max_depth=7, max_features=5, n_estimators=400;, score=(train=0.953, test=0.899) total time=   0.9s
# [CV 2/5; 30/64] START max_depth=7, max_features=7, n_estimators=200.............
# [CV 2/5; 30/64] END max_depth=7, max_features=7, n_estimators=200;, score=(train=0.964, test=0.862) total time=   0.5s
# [CV 1/5; 32/64] START max_depth=7, max_features=7, n_estimators=400.............
# [CV 1/5; 32/64] END max_depth=7, max_features=7, n_estimators=400;, score=(train=0.953, test=0.866) total time=   0.9s
# [CV 1/5; 34/64] START max_depth=8, max_features=1, n_estimators=200.............
# [CV 1/5; 34/64] END max_depth=8, max_features=1, n_estimators=200;, score=(train=0.956, test=0.877) total time=   0.6s
# [CV 3/5; 35/64] START max_depth=8, max_features=1, n_estimators=300.............
# [CV 3/5; 35/64] END max_depth=8, max_features=1, n_estimators=300;, score=(train=0.955, test=0.895) total time=   1.0s
# [CV 2/5; 37/64] START max_depth=8, max_features=3, n_estimators=100.............
# [CV 2/5; 37/64] END max_depth=8, max_features=3, n_estimators=100;, score=(train=0.966, test=0.858) total time=   0.3s
# [CV 1/5; 38/64] START max_depth=8, max_features=3, n_estimators=200.............
# [CV 1/5; 38/64] END max_depth=8, max_features=3, n_estimators=200;, score=(train=0.957, test=0.876) total time=   0.5s
# [CV 4/5; 39/64] START max_depth=8, max_features=3, n_estimators=300.............
# [CV 4/5; 39/64] END max_depth=8, max_features=3, n_estimators=300;, score=(train=0.955, test=0.915) total time=   0.9s
# [CV 2/5; 41/64] START max_depth=8, max_features=5, n_estimators=100.............
# [CV 2/5; 41/64] END max_depth=8, max_features=5, n_estimators=100;, score=(train=0.967, test=0.860) total time=   0.5s
# [CV 4/5; 42/64] START max_depth=8, max_features=5, n_estimators=200.............
# [CV 4/5; 42/64] END max_depth=8, max_features=5, n_estimators=200;, score=(train=0.957, test=0.914) total time=   0.6s
# [CV 2/5; 44/64] START max_depth=8, max_features=5, n_estimators=400.............
# [CV 2/5; 44/64] END max_depth=8, max_features=5, n_estimators=400;, score=(train=0.968, test=0.861) total time=   1.2s
# [CV 3/5; 46/64] START max_depth=8, max_features=7, n_estimators=200.............
# [CV 3/5; 46/64] END max_depth=8, max_features=7, n_estimators=200;, score=(train=0.957, test=0.909) total time=   0.7s
# [CV 1/5; 48/64] START max_depth=8, max_features=7, n_estimators=400.............
# [CV 1/5; 48/64] END max_depth=8, max_features=7, n_estimators=400;, score=(train=0.959, test=0.866) total time=   1.2s
# [CV 4/5; 50/64] START max_depth=9, max_features=1, n_estimators=200.............
# [CV 4/5; 50/64] END max_depth=9, max_features=1, n_estimators=200;, score=(train=0.956, test=0.907) total time=   0.5s
# [CV 2/5; 52/64] START max_depth=9, max_features=1, n_estimators=400.............
# [CV 2/5; 52/64] END max_depth=9, max_features=1, n_estimators=400;, score=(train=0.970, test=0.856) total time=   1.3s
# [CV 4/5; 54/64] START max_depth=9, max_features=3, n_estimators=200.............
# [CV 4/5; 54/64] END max_depth=9, max_features=3, n_estimators=200;, score=(train=0.958, test=0.913) total time=   0.6s
# [CV 3/5; 56/64] START max_depth=9, max_features=3, n_estimators=400.............
# [CV 3/5; 56/64] END max_depth=9, max_features=3, n_estimators=400;, score=(train=0.959, test=0.896) total time=   1.3s
# [CV 2/5; 58/64] START max_depth=9, max_features=5, n_estimators=200.............
# [CV 2/5; 58/64] END max_depth=9, max_features=5, n_estimators=200;, score=(train=0.970, test=0.860) total time=   0.5s
# [CV 4/5; 59/64] START max_depth=9, max_features=5, n_estimators=300.............
# [CV 4/5; 59/64] END max_depth=9, max_features=5, n_estimators=300;, score=(train=0.958, test=0.915) total time=   0.9s
# [CV 2/5; 61/64] START max_depth=9, max_features=7, n_estimators=100.............
# [CV 2/5; 61/64] END max_depth=9, max_features=7, n_estimators=100;, score=(train=0.970, test=0.861) total time=   0.3s
# [CV 5/5; 61/64] START max_depth=9, max_features=7, n_estimators=100.............
# [CV 5/5; 61/64] END max_depth=9, max_features=7, n_estimators=100;, score=(train=0.966, test=0.858) total time=   0.3s
# [CV 1/5; 63/64] START max_depth=9, max_features=7, n_estimators=300.............
# [CV 1/5; 63/64] END max_depth=9, max_features=7, n_estimators=300;, score=(train=0.961, test=0.864) total time=   0.8s
# [CV 4/5; 64/64] START max_depth=9, max_features=7, n_estimators=400.............
# [CV 4/5; 64/64] END max_depth=9, max_features=7, n_estimators=400;, score=(train=0.959, test=0.916) total time=   0.8s
# [CV 3/5; 1/64] START max_depth=6, max_features=1, n_estimators=100..............
# [CV 3/5; 1/64] END max_depth=6, max_features=1, n_estimators=100;, score=(train=0.931, test=0.899) total time=   0.2s
# [CV 4/5; 2/64] START max_depth=6, max_features=1, n_estimators=200..............
# [CV 4/5; 2/64] END max_depth=6, max_features=1, n_estimators=200;, score=(train=0.930, test=0.901) total time=   0.3s
# [CV 2/5; 4/64] START max_depth=6, max_features=1, n_estimators=400..............
# [CV 2/5; 4/64] END max_depth=6, max_features=1, n_estimators=400;, score=(train=0.945, test=0.843) total time=   0.7s
# [CV 4/5; 6/64] START max_depth=6, max_features=3, n_estimators=200..............
# [CV 4/5; 6/64] END max_depth=6, max_features=3, n_estimators=200;, score=(train=0.938, test=0.918) total time=   0.4s
# [CV 1/5; 8/64] START max_depth=6, max_features=3, n_estimators=400..............
# [CV 1/5; 8/64] END max_depth=6, max_features=3, n_estimators=400;, score=(train=0.940, test=0.874) total time=   0.7s
# [CV 5/5; 9/64] START max_depth=6, max_features=5, n_estimators=100..............
# [CV 5/5; 9/64] END max_depth=6, max_features=5, n_estimators=100;, score=(train=0.952, test=0.885) total time=   0.2s
# [CV 1/5; 11/64] START max_depth=6, max_features=5, n_estimators=300.............
# [CV 1/5; 11/64] END max_depth=6, max_features=5, n_estimators=300;, score=(train=0.943, test=0.868) total time=   0.5s
# [CV 4/5; 12/64] START max_depth=6, max_features=5, n_estimators=400.............
# [CV 4/5; 12/64] END max_depth=6, max_features=5, n_estimators=400;, score=(train=0.943, test=0.922) total time=   0.8s
# [CV 2/5; 15/64] START max_depth=6, max_features=7, n_estimators=300.............
# [CV 2/5; 15/64] END max_depth=6, max_features=7, n_estimators=300;, score=(train=0.954, test=0.859) total time=   0.5s
# [CV 5/5; 16/64] START max_depth=6, max_features=7, n_estimators=400.............
# [CV 5/5; 16/64] END max_depth=6, max_features=7, n_estimators=400;, score=(train=0.955, test=0.874) total time=   0.8s
# [CV 3/5; 19/64] START max_depth=7, max_features=1, n_estimators=300.............
# [CV 3/5; 19/64] END max_depth=7, max_features=1, n_estimators=300;, score=(train=0.949, test=0.896) total time=   0.6s
# [CV 1/5; 21/64] START max_depth=7, max_features=3, n_estimators=100.............
# [CV 1/5; 21/64] END max_depth=7, max_features=3, n_estimators=100;, score=(train=0.950, test=0.874) total time=   0.2s
# [CV 4/5; 21/64] START max_depth=7, max_features=3, n_estimators=100.............
# [CV 4/5; 21/64] END max_depth=7, max_features=3, n_estimators=100;, score=(train=0.947, test=0.914) total time=   0.2s
# [CV 5/5; 22/64] START max_depth=7, max_features=3, n_estimators=200.............
# [CV 5/5; 22/64] END max_depth=7, max_features=3, n_estimators=200;, score=(train=0.957, test=0.873) total time=   0.4s
# [CV 3/5; 24/64] START max_depth=7, max_features=3, n_estimators=400.............
# [CV 3/5; 24/64] END max_depth=7, max_features=3, n_estimators=400;, score=(train=0.950, test=0.901) total time=   0.9s
# [CV 5/5; 25/64] START max_depth=7, max_features=5, n_estimators=100.............
# [CV 5/5; 25/64] END max_depth=7, max_features=5, n_estimators=100;, score=(train=0.958, test=0.869) total time=   0.2s
# [CV 1/5; 27/64] START max_depth=7, max_features=5, n_estimators=300.............
# [CV 1/5; 27/64] END max_depth=7, max_features=5, n_estimators=300;, score=(train=0.953, test=0.869) total time=   0.6s
# [CV 4/5; 28/64] START max_depth=7, max_features=5, n_estimators=400.............
# [CV 4/5; 28/64] END max_depth=7, max_features=5, n_estimators=400;, score=(train=0.952, test=0.918) total time=   0.9s
# [CV 2/5; 31/64] START max_depth=7, max_features=7, n_estimators=300.............
# [CV 2/5; 31/64] END max_depth=7, max_features=7, n_estimators=300;, score=(train=0.964, test=0.863) total time=   0.6s
# [CV 5/5; 32/64] START max_depth=7, max_features=7, n_estimators=400.............
# [CV 5/5; 32/64] END max_depth=7, max_features=7, n_estimators=400;, score=(train=0.962, test=0.864) total time=   1.1s
# [CV 2/5; 36/64] START max_depth=8, max_features=1, n_estimators=400.............
# [CV 2/5; 36/64] END max_depth=8, max_features=1, n_estimators=400;, score=(train=0.966, test=0.855) total time=   1.1s
# [CV 5/5; 37/64] START max_depth=8, max_features=3, n_estimators=100.............
# [CV 5/5; 37/64] END max_depth=8, max_features=3, n_estimators=100;, score=(train=0.961, test=0.873) total time=   0.3s
# [CV 1/5; 39/64] START max_depth=8, max_features=3, n_estimators=300.............
# [CV 1/5; 39/64] END max_depth=8, max_features=3, n_estimators=300;, score=(train=0.957, test=0.872) total time=   0.8s
# [CV 4/5; 40/64] START max_depth=8, max_features=3, n_estimators=400.............
# [CV 4/5; 40/64] END max_depth=8, max_features=3, n_estimators=400;, score=(train=0.956, test=0.914) total time=   1.2s
# [CV 2/5; 43/64] START max_depth=8, max_features=5, n_estimators=300.............
# [CV 2/5; 43/64] END max_depth=8, max_features=5, n_estimators=300;, score=(train=0.967, test=0.861) total time=   0.8s
# [CV 5/5; 44/64] START max_depth=8, max_features=5, n_estimators=400.............
# [CV 5/5; 44/64] END max_depth=8, max_features=5, n_estimators=400;, score=(train=0.964, test=0.859) total time=   1.1s
# [CV 3/5; 47/64] START max_depth=8, max_features=7, n_estimators=300.............
# [CV 3/5; 47/64] END max_depth=8, max_features=7, n_estimators=300;, score=(train=0.958, test=0.904) total time=   0.9s
# [CV 1/5; 49/64] START max_depth=9, max_features=1, n_estimators=100.............
# [CV 1/5; 49/64] END max_depth=9, max_features=1, n_estimators=100;, score=(train=0.960, test=0.853) total time=   0.3s
# [CV 4/5; 49/64] START max_depth=9, max_features=1, n_estimators=100.............
# [CV 4/5; 49/64] END max_depth=9, max_features=1, n_estimators=100;, score=(train=0.954, test=0.906) total time=   0.3s
# [CV 5/5; 50/64] START max_depth=9, max_features=1, n_estimators=200.............
# [CV 5/5; 50/64] END max_depth=9, max_features=1, n_estimators=200;, score=(train=0.963, test=0.863) total time=   0.5s
# [CV 3/5; 52/64] START max_depth=9, max_features=1, n_estimators=400.............
# [CV 3/5; 52/64] END max_depth=9, max_features=1, n_estimators=400;, score=(train=0.959, test=0.893) total time=   1.2s
# [CV 5/5; 53/64] START max_depth=9, max_features=3, n_estimators=100.............
# [CV 5/5; 53/64] END max_depth=9, max_features=3, n_estimators=100;, score=(train=0.963, test=0.860) total time=   0.3s
# [CV 1/5; 55/64] START max_depth=9, max_features=3, n_estimators=300.............
# [CV 1/5; 55/64] END max_depth=9, max_features=3, n_estimators=300;, score=(train=0.960, test=0.871) total time=   1.0s
# [CV 4/5; 56/64] START max_depth=9, max_features=3, n_estimators=400.............
# [CV 4/5; 56/64] END max_depth=9, max_features=3, n_estimators=400;, score=(train=0.958, test=0.913) total time=   1.1s
# [CV 2/5; 59/64] START max_depth=9, max_features=5, n_estimators=300.............
# [CV 2/5; 59/64] END max_depth=9, max_features=5, n_estimators=300;, score=(train=0.971, test=0.861) total time=   0.9s
# [CV 4/5; 60/64] START max_depth=9, max_features=5, n_estimators=400.............
# [CV 4/5; 60/64] END max_depth=9, max_features=5, n_estimators=400;, score=(train=0.959, test=0.915) total time=   1.1s
# [CV 2/5; 63/64] START max_depth=9, max_features=7, n_estimators=300.............
# [CV 2/5; 63/64] END max_depth=9, max_features=7, n_estimators=300;, score=(train=0.971, test=0.862) total time=   0.8s
# [CV 5/5; 64/64] START max_depth=9, max_features=7, n_estimators=400.............
# [CV 5/5; 64/64] END max_depth=9, max_features=7, n_estimators=400;, score=(train=0.966, test=0.854) total time=   0.6s
